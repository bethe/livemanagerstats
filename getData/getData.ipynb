# %%
import json
import requests
import pprint
import os
import re
import time
import datetime

# %% [markdown]
# ## Part 1: Downloading data from API and joining in one big JSON file

# %%
start_time = time.time()
print "Starting at " + str(datetime.datetime.fromtimestamp(start_time))
BASE_URL = "http://www.playlivemanager.com/api/players/"
ROUND_URL_EXT = "/stats/round"
PLAYER_IDs = range(64400,66800)
# Out:
# Starting at 2016-03-14 12:37:50.910530

# %%
def query_by_id(playerID):
    print "Processing Player with ID " + playerID
    url = BASE_URL + playerID + ROUND_URL_EXT
    r = requests.get(url)
    print "requesting", r.url
    print r

    if r.status_code == requests.codes.ok:
        return r.json()
        print r.json()
    else:
        r.raise_for_status()

# %%
def download_data():
    for playerID in PLAYER_IDs:        
        results = query_by_id(str(playerID))
#        pprint.pprint(results)
        with open("../data/{0}.json".format(playerID), mode='w') as f:
            json.dump(results, f)
            print "Stored data for player " + str(playerID) + " in " + f.name

# %%
def transform_data():
    print "Deleting old files"
    try:
        os.remove("../data/all.json")
    except:
        pass
    print "Begin transforming data"
    for playerID in PLAYER_IDs:
        with open("../data/all.json", mode='a') as all:
            f = open("../data/{0}.json".format(playerID), 'r')
            print "Processing " + f.name
            file = f.read()
            file = file.strip()
            ## remove root
            file = re.sub('{\"status\": \"ok\", \"response\": \[', "", file)
            ## remove superfluous ']}' at the end and replace with ','
            file = re.sub("}}]}]}", "}}]},", file)
            #aggregate in one big json file
            #json.dump(file, all)
            all.write(file)
            #all.close()
            print "Added " + f.name + " to " + all.name

    # wrap content in '[]', replacing last ','
    with open("../data/allfinal.json", mode='w') as all:
        print "Wrapping file in json format"
        reader = open("../data/all.json", 'r').read()
        reader = '[' + reader
        reader = re.sub(r"\,$", r"]", reader)
        reader = reader.strip()
        all.write("%s\n" % reader)
    
    print "All data stored in " + all.name

# %%
download_data()
# Out:
# Processing Player with ID 64400
# requesting http://www.playlivemanager.com/api/players/64400/stats/round
# <Response [200]>
# Stored data for player 64400 in ../data/64400.json
# Processing Player with ID 64401
# requesting http://www.playlivemanager.com/api/players/64401/stats/round
# <Response [200]>
# Stored data for player 64401 in ../data/64401.json
# Processing Player with ID 64402
# requesting http://www.playlivemanager.com/api/players/64402/stats/round
# <Response [200]>
# Stored data for player 64402 in ../data/64402.json
# Processing Player with ID 64403
# requesting http://www.playlivemanager.com/api/players/64403/stats/round
# <Response [200]>
# Stored data for player 64403 in ../data/64403.json
# Processing Player with ID 64404
# requesting http://www.playlivemanager.com/api/players/64404/stats/round
# <Response [200]>
# Stored data for player 64404 in ../data/64404.json
# Processing Player with ID 64405
# requesting http://www.playlivemanager.com/api/players/64405/stats/round
# <Response [200]>
# Stored data for player 64405 in ../data/64405.json
# Processing Player with ID 64406
# requesting http://www.playlivemanager.com/api/players/64406/stats/round
# <Response [200]>
# Stored data for player 64406 in ../data/64406.json
# Processing Player with ID 64407
# requesting http://www.playlivemanager.com/api/players/64407/stats/round
# <Response [200]>
# Stored data for player 64407 in ../data/64407.json
# Processing Player with ID 64408
# requesting http://www.playlivemanager.com/api/players/64408/stats/round
# <Response [200]>
# Stored data for player 64408 in ../data/64408.json
# Processing Player with ID 64409
# requesting http://www.playlivemanager.com/api/players/64409/stats/round
# <Response [200]>
# Stored data for player 64409 in ../data/64409.json
# Processing Player with ID 64410
# requesting http://www.playlivemanager.com/api/players/64410/stats/round
# <Response [200]>
# Stored data for player 64410 in ../data/64410.json
# Processing Player with ID 64411
# requesting http://www.playlivemanager.com/api/players/64411/stats/round
# <Response [200]>
# Stored data for player 64411 in ../data/64411.json
# Processing Player with ID 64412
# requesting http://www.playlivemanager.com/api/players/64412/stats/round
# <Response [200]>
# Stored data for player 64412 in ../data/64412.json
# Processing Player with ID 64413
# requesting http://www.playlivemanager.com/api/players/64413/stats/round
# <Response [200]>
# Stored data for player 64413 in ../data/64413.json
# Processing Player with ID 64414
# requesting http://www.playlivemanager.com/api/players/64414/stats/round
# <Response [200]>
# Stored data for player 64414 in ../data/64414.json
# Processing Player with ID 64415
# requesting http://www.playlivemanager.com/api/players/64415/stats/round
# <Response [200]>
# Stored data for player 64415 in ../data/64415.json
# Processing Player with ID 64416
# requesting http://www.playlivemanager.com/api/players/64416/stats/round
# <Response [200]>
# Stored data for player 64416 in ../data/64416.json
# Processing Player with ID 64417
# requesting http://www.playlivemanager.com/api/players/64417/stats/round
# <Response [200]>
# Stored data for player 64417 in ../data/64417.json
# Processing Player with ID 64418
# requesting http://www.playlivemanager.com/api/players/64418/stats/round
# <Response [200]>
# Stored data for player 64418 in ../data/64418.json
# Processing Player with ID 64419
# requesting http://www.playlivemanager.com/api/players/64419/stats/round
# <Response [200]>
# Stored data for player 64419 in ../data/64419.json
# Processing Player with ID 64420
# requesting http://www.playlivemanager.com/api/players/64420/stats/round
# <Response [200]>
# Stored data for player 64420 in ../data/64420.json
# Processing Player with ID 64421
# requesting http://www.playlivemanager.com/api/players/64421/stats/round
# <Response [200]>
# Stored data for player 64421 in ../data/64421.json
# Processing Player with ID 64422
# requesting http://www.playlivemanager.com/api/players/64422/stats/round
# <Response [200]>
# Stored data for player 64422 in ../data/64422.json
# Processing Player with ID 64423
# requesting http://www.playlivemanager.com/api/players/64423/stats/round
# <Response [200]>
# Stored data for player 64423 in ../data/64423.json
# Processing Player with ID 64424
# requesting http://www.playlivemanager.com/api/players/64424/stats/round
# <Response [200]>
# Stored data for player 64424 in ../data/64424.json
# Processing Player with ID 64425
# requesting http://www.playlivemanager.com/api/players/64425/stats/round
# <Response [200]>
# Stored data for player 64425 in ../data/64425.json
# Processing Player with ID 64426
# requesting http://www.playlivemanager.com/api/players/64426/stats/round
# <Response [200]>
# Stored data for player 64426 in ../data/64426.json
# Processing Player with ID 64427
# requesting http://www.playlivemanager.com/api/players/64427/stats/round
# <Response [200]>
# Stored data for player 64427 in ../data/64427.json
# Processing Player with ID 64428
# requesting http://www.playlivemanager.com/api/players/64428/stats/round
# <Response [200]>
# Stored data for player 64428 in ../data/64428.json
# Processing Player with ID 64429
# requesting http://www.playlivemanager.com/api/players/64429/stats/round
# <Response [200]>
# Stored data for player 64429 in ../data/64429.json
# Processing Player with ID 64430
# requesting http://www.playlivemanager.com/api/players/64430/stats/round
# <Response [200]>
# Stored data for player 64430 in ../data/64430.json
# Processing Player with ID 64431
# requesting http://www.playlivemanager.com/api/players/64431/stats/round
# <Response [200]>
# Stored data for player 64431 in ../data/64431.json
# Processing Player with ID 64432
# requesting http://www.playlivemanager.com/api/players/64432/stats/round
# <Response [200]>
# Stored data for player 64432 in ../data/64432.json
# Processing Player with ID 64433
# requesting http://www.playlivemanager.com/api/players/64433/stats/round
# <Response [200]>
# Stored data for player 64433 in ../data/64433.json
# Processing Player with ID 64434
# requesting http://www.playlivemanager.com/api/players/64434/stats/round
# <Response [200]>
# Stored data for player 64434 in ../data/64434.json
# Processing Player with ID 64435
# requesting http://www.playlivemanager.com/api/players/64435/stats/round
# <Response [200]>
# Stored data for player 64435 in ../data/64435.json
# Processing Player with ID 64436
# requesting http://www.playlivemanager.com/api/players/64436/stats/round
# <Response [200]>
# Stored data for player 64436 in ../data/64436.json
# Processing Player with ID 64437
# requesting http://www.playlivemanager.com/api/players/64437/stats/round
# <Response [200]>
# Stored data for player 64437 in ../data/64437.json
# Processing Player with ID 64438
# requesting http://www.playlivemanager.com/api/players/64438/stats/round
# <Response [200]>
# Stored data for player 64438 in ../data/64438.json
# Processing Player with ID 64439
# requesting http://www.playlivemanager.com/api/players/64439/stats/round
# <Response [200]>
# Stored data for player 64439 in ../data/64439.json
# Processing Player with ID 64440
# requesting http://www.playlivemanager.com/api/players/64440/stats/round
# <Response [200]>
# Stored data for player 64440 in ../data/64440.json
# Processing Player with ID 64441
# requesting http://www.playlivemanager.com/api/players/64441/stats/round
# <Response [200]>
# Stored data for player 64441 in ../data/64441.json
# Processing Player with ID 64442
# requesting http://www.playlivemanager.com/api/players/64442/stats/round
# <Response [200]>
# Stored data for player 64442 in ../data/64442.json
# Processing Player with ID 64443
# requesting http://www.playlivemanager.com/api/players/64443/stats/round
# <Response [200]>
# Stored data for player 64443 in ../data/64443.json
# Processing Player with ID 64444
# requesting http://www.playlivemanager.com/api/players/64444/stats/round
# <Response [200]>
# Stored data for player 64444 in ../data/64444.json
# Processing Player with ID 64445
# requesting http://www.playlivemanager.com/api/players/64445/stats/round
# <Response [200]>
# Stored data for player 64445 in ../data/64445.json
# Processing Player with ID 64446
# requesting http://www.playlivemanager.com/api/players/64446/stats/round
# <Response [200]>
# Stored data for player 64446 in ../data/64446.json
# Processing Player with ID 64447
# requesting http://www.playlivemanager.com/api/players/64447/stats/round
# <Response [200]>
# Stored data for player 64447 in ../data/64447.json
# Processing Player with ID 64448
# requesting http://www.playlivemanager.com/api/players/64448/stats/round
# <Response [200]>
# Stored data for player 64448 in ../data/64448.json
# Processing Player with ID 64449
# requesting http://www.playlivemanager.com/api/players/64449/stats/round
# <Response [200]>
# Stored data for player 64449 in ../data/64449.json
# Processing Player with ID 64450
# requesting http://www.playlivemanager.com/api/players/64450/stats/round
# <Response [200]>
# Stored data for player 64450 in ../data/64450.json
# Processing Player with ID 64451
# requesting http://www.playlivemanager.com/api/players/64451/stats/round
# <Response [200]>
# Stored data for player 64451 in ../data/64451.json
# Processing Player with ID 64452
# requesting http://www.playlivemanager.com/api/players/64452/stats/round
# <Response [200]>
# Stored data for player 64452 in ../data/64452.json
# Processing Player with ID 64453
# requesting http://www.playlivemanager.com/api/players/64453/stats/round
# <Response [200]>
# Stored data for player 64453 in ../data/64453.json
# Processing Player with ID 64454
# requesting http://www.playlivemanager.com/api/players/64454/stats/round
# <Response [200]>
# Stored data for player 64454 in ../data/64454.json
# Processing Player with ID 64455
# requesting http://www.playlivemanager.com/api/players/64455/stats/round
# <Response [200]>
# Stored data for player 64455 in ../data/64455.json
# Processing Player with ID 64456
# requesting http://www.playlivemanager.com/api/players/64456/stats/round
# <Response [200]>
# Stored data for player 64456 in ../data/64456.json
# Processing Player with ID 64457
# requesting http://www.playlivemanager.com/api/players/64457/stats/round
# <Response [200]>
# Stored data for player 64457 in ../data/64457.json
# Processing Player with ID 64458
# requesting http://www.playlivemanager.com/api/players/64458/stats/round
# <Response [200]>
# Stored data for player 64458 in ../data/64458.json
# Processing Player with ID 64459
# requesting http://www.playlivemanager.com/api/players/64459/stats/round
# <Response [200]>
# Stored data for player 64459 in ../data/64459.json
# Processing Player with ID 64460
# requesting http://www.playlivemanager.com/api/players/64460/stats/round
# <Response [200]>
# Stored data for player 64460 in ../data/64460.json
# Processing Player with ID 64461
# requesting http://www.playlivemanager.com/api/players/64461/stats/round
# <Response [200]>
# Stored data for player 64461 in ../data/64461.json
# Processing Player with ID 64462
# requesting http://www.playlivemanager.com/api/players/64462/stats/round
# <Response [200]>
# Stored data for player 64462 in ../data/64462.json
# Processing Player with ID 64463
# requesting http://www.playlivemanager.com/api/players/64463/stats/round
# <Response [200]>
# Stored data for player 64463 in ../data/64463.json
# Processing Player with ID 64464
# requesting http://www.playlivemanager.com/api/players/64464/stats/round
# <Response [200]>
# Stored data for player 64464 in ../data/64464.json
# Processing Player with ID 64465
# requesting http://www.playlivemanager.com/api/players/64465/stats/round
# <Response [200]>
# Stored data for player 64465 in ../data/64465.json
# Processing Player with ID 64466
# requesting http://www.playlivemanager.com/api/players/64466/stats/round
# <Response [200]>
# Stored data for player 64466 in ../data/64466.json
# Processing Player with ID 64467
# requesting http://www.playlivemanager.com/api/players/64467/stats/round
# <Response [200]>
# Stored data for player 64467 in ../data/64467.json
# Processing Player with ID 64468
# requesting http://www.playlivemanager.com/api/players/64468/stats/round
# <Response [200]>
# Stored data for player 64468 in ../data/64468.json
# Processing Player with ID 64469
# requesting http://www.playlivemanager.com/api/players/64469/stats/round
# <Response [200]>
# Stored data for player 64469 in ../data/64469.json
# Processing Player with ID 64470
# requesting http://www.playlivemanager.com/api/players/64470/stats/round
# <Response [200]>
# Stored data for player 64470 in ../data/64470.json
# Processing Player with ID 64471
# requesting http://www.playlivemanager.com/api/players/64471/stats/round
# <Response [200]>
# Stored data for player 64471 in ../data/64471.json
# Processing Player with ID 64472
# requesting http://www.playlivemanager.com/api/players/64472/stats/round
# <Response [200]>
# Stored data for player 64472 in ../data/64472.json
# Processing Player with ID 64473
# requesting http://www.playlivemanager.com/api/players/64473/stats/round
# <Response [200]>
# Stored data for player 64473 in ../data/64473.json
# Processing Player with ID 64474
# requesting http://www.playlivemanager.com/api/players/64474/stats/round
# <Response [200]>
# Stored data for player 64474 in ../data/64474.json
# Processing Player with ID 64475
# requesting http://www.playlivemanager.com/api/players/64475/stats/round
# <Response [200]>
# Stored data for player 64475 in ../data/64475.json
# Processing Player with ID 64476
# requesting http://www.playlivemanager.com/api/players/64476/stats/round
# <Response [200]>
# Stored data for player 64476 in ../data/64476.json
# Processing Player with ID 64477
# requesting http://www.playlivemanager.com/api/players/64477/stats/round
# <Response [200]>
# Stored data for player 64477 in ../data/64477.json
# Processing Player with ID 64478
# requesting http://www.playlivemanager.com/api/players/64478/stats/round
# <Response [200]>
# Stored data for player 64478 in ../data/64478.json
# Processing Player with ID 64479
# requesting http://www.playlivemanager.com/api/players/64479/stats/round
# <Response [200]>
# Stored data for player 64479 in ../data/64479.json
# Processing Player with ID 64480
# requesting http://www.playlivemanager.com/api/players/64480/stats/round
# <Response [200]>
# Stored data for player 64480 in ../data/64480.json
# Processing Player with ID 64481
# requesting http://www.playlivemanager.com/api/players/64481/stats/round
# <Response [200]>
# Stored data for player 64481 in ../data/64481.json
# Processing Player with ID 64482
# requesting http://www.playlivemanager.com/api/players/64482/stats/round
# <Response [200]>
# Stored data for player 64482 in ../data/64482.json
# Processing Player with ID 64483
# requesting http://www.playlivemanager.com/api/players/64483/stats/round
# <Response [200]>
# Stored data for player 64483 in ../data/64483.json
# Processing Player with ID 64484
# requesting http://www.playlivemanager.com/api/players/64484/stats/round
# <Response [200]>
# Stored data for player 64484 in ../data/64484.json
# Processing Player with ID 64485
# requesting http://www.playlivemanager.com/api/players/64485/stats/round
# <Response [200]>
# Stored data for player 64485 in ../data/64485.json
# Processing Player with ID 64486
# requesting http://www.playlivemanager.com/api/players/64486/stats/round
# <Response [200]>
# Stored data for player 64486 in ../data/64486.json
# Processing Player with ID 64487
# requesting http://www.playlivemanager.com/api/players/64487/stats/round
# <Response [200]>
# Stored data for player 64487 in ../data/64487.json
# Processing Player with ID 64488
# requesting http://www.playlivemanager.com/api/players/64488/stats/round
# <Response [200]>
# Stored data for player 64488 in ../data/64488.json
# Processing Player with ID 64489
# requesting http://www.playlivemanager.com/api/players/64489/stats/round
# <Response [200]>
# Stored data for player 64489 in ../data/64489.json
# Processing Player with ID 64490
# requesting http://www.playlivemanager.com/api/players/64490/stats/round
# <Response [200]>
# Stored data for player 64490 in ../data/64490.json
# Processing Player with ID 64491
# requesting http://www.playlivemanager.com/api/players/64491/stats/round
# <Response [200]>
# Stored data for player 64491 in ../data/64491.json
# Processing Player with ID 64492
# requesting http://www.playlivemanager.com/api/players/64492/stats/round
# <Response [200]>
# Stored data for player 64492 in ../data/64492.json
# Processing Player with ID 64493
# requesting http://www.playlivemanager.com/api/players/64493/stats/round
# <Response [200]>
# Stored data for player 64493 in ../data/64493.json
# Processing Player with ID 64494
# requesting http://www.playlivemanager.com/api/players/64494/stats/round
# <Response [200]>
# Stored data for player 64494 in ../data/64494.json
# Processing Player with ID 64495
# requesting http://www.playlivemanager.com/api/players/64495/stats/round
# <Response [200]>
# Stored data for player 64495 in ../data/64495.json
# Processing Player with ID 64496
# requesting http://www.playlivemanager.com/api/players/64496/stats/round
# <Response [200]>
# Stored data for player 64496 in ../data/64496.json
# Processing Player with ID 64497
# requesting http://www.playlivemanager.com/api/players/64497/stats/round
# <Response [200]>
# Stored data for player 64497 in ../data/64497.json
# Processing Player with ID 64498
# requesting http://www.playlivemanager.com/api/players/64498/stats/round
# <Response [200]>
# Stored data for player 64498 in ../data/64498.json
# Processing Player with ID 64499
# requesting http://www.playlivemanager.com/api/players/64499/stats/round
# <Response [200]>
# Stored data for player 64499 in ../data/64499.json
# Processing Player with ID 64500
# requesting http://www.playlivemanager.com/api/players/64500/stats/round
# <Response [200]>
# Stored data for player 64500 in ../data/64500.json
# Processing Player with ID 64501
# requesting http://www.playlivemanager.com/api/players/64501/stats/round
# <Response [200]>
# Stored data for player 64501 in ../data/64501.json
# Processing Player with ID 64502
# requesting http://www.playlivemanager.com/api/players/64502/stats/round
# <Response [200]>
# Stored data for player 64502 in ../data/64502.json
# Processing Player with ID 64503
# requesting http://www.playlivemanager.com/api/players/64503/stats/round
# <Response [200]>
# Stored data for player 64503 in ../data/64503.json
# Processing Player with ID 64504
# requesting http://www.playlivemanager.com/api/players/64504/stats/round
# <Response [200]>
# Stored data for player 64504 in ../data/64504.json
# Processing Player with ID 64505
# requesting http://www.playlivemanager.com/api/players/64505/stats/round
# <Response [200]>
# Stored data for player 64505 in ../data/64505.json
# Processing Player with ID 64506
# requesting http://www.playlivemanager.com/api/players/64506/stats/round
# <Response [200]>
# Stored data for player 64506 in ../data/64506.json
# Processing Player with ID 64507
# requesting http://www.playlivemanager.com/api/players/64507/stats/round
# <Response [200]>
# Stored data for player 64507 in ../data/64507.json
# Processing Player with ID 64508
# requesting http://www.playlivemanager.com/api/players/64508/stats/round
# <Response [200]>
# Stored data for player 64508 in ../data/64508.json
# Processing Player with ID 64509
# requesting http://www.playlivemanager.com/api/players/64509/stats/round
# <Response [200]>
# Stored data for player 64509 in ../data/64509.json
# Processing Player with ID 64510
# requesting http://www.playlivemanager.com/api/players/64510/stats/round
# <Response [200]>
# Stored data for player 64510 in ../data/64510.json
# Processing Player with ID 64511
# requesting http://www.playlivemanager.com/api/players/64511/stats/round
# <Response [200]>
# Stored data for player 64511 in ../data/64511.json
# Processing Player with ID 64512
# requesting http://www.playlivemanager.com/api/players/64512/stats/round
# <Response [200]>
# Stored data for player 64512 in ../data/64512.json
# Processing Player with ID 64513
# requesting http://www.playlivemanager.com/api/players/64513/stats/round
# <Response [200]>
# Stored data for player 64513 in ../data/64513.json
# Processing Player with ID 64514
# requesting http://www.playlivemanager.com/api/players/64514/stats/round
# <Response [200]>
# Stored data for player 64514 in ../data/64514.json
# Processing Player with ID 64515
# requesting http://www.playlivemanager.com/api/players/64515/stats/round
# <Response [200]>
# Stored data for player 64515 in ../data/64515.json
# Processing Player with ID 64516
# requesting http://www.playlivemanager.com/api/players/64516/stats/round
# <Response [200]>
# Stored data for player 64516 in ../data/64516.json
# Processing Player with ID 64517
# requesting http://www.playlivemanager.com/api/players/64517/stats/round
# <Response [200]>
# Stored data for player 64517 in ../data/64517.json
# Processing Player with ID 64518
# requesting http://www.playlivemanager.com/api/players/64518/stats/round
# <Response [200]>
# Stored data for player 64518 in ../data/64518.json
# Processing Player with ID 64519
# requesting http://www.playlivemanager.com/api/players/64519/stats/round
# <Response [200]>
# Stored data for player 64519 in ../data/64519.json
# Processing Player with ID 64520
# requesting http://www.playlivemanager.com/api/players/64520/stats/round
# <Response [200]>
# Stored data for player 64520 in ../data/64520.json
# Processing Player with ID 64521
# requesting http://www.playlivemanager.com/api/players/64521/stats/round
# <Response [200]>
# Stored data for player 64521 in ../data/64521.json
# Processing Player with ID 64522
# requesting http://www.playlivemanager.com/api/players/64522/stats/round
# <Response [200]>
# Stored data for player 64522 in ../data/64522.json
# Processing Player with ID 64523
# requesting http://www.playlivemanager.com/api/players/64523/stats/round
# <Response [200]>
# Stored data for player 64523 in ../data/64523.json
# Processing Player with ID 64524
# requesting http://www.playlivemanager.com/api/players/64524/stats/round
# <Response [200]>
# Stored data for player 64524 in ../data/64524.json
# Processing Player with ID 64525
# requesting http://www.playlivemanager.com/api/players/64525/stats/round
# <Response [200]>
# Stored data for player 64525 in ../data/64525.json
# Processing Player with ID 64526
# requesting http://www.playlivemanager.com/api/players/64526/stats/round
# <Response [200]>
# Stored data for player 64526 in ../data/64526.json
# Processing Player with ID 64527
# requesting http://www.playlivemanager.com/api/players/64527/stats/round
# <Response [200]>
# Stored data for player 64527 in ../data/64527.json
# Processing Player with ID 64528
# requesting http://www.playlivemanager.com/api/players/64528/stats/round
# <Response [200]>
# Stored data for player 64528 in ../data/64528.json
# Processing Player with ID 64529
# requesting http://www.playlivemanager.com/api/players/64529/stats/round
# <Response [200]>
# Stored data for player 64529 in ../data/64529.json
# Processing Player with ID 64530
# requesting http://www.playlivemanager.com/api/players/64530/stats/round
# <Response [200]>
# Stored data for player 64530 in ../data/64530.json
# Processing Player with ID 64531
# requesting http://www.playlivemanager.com/api/players/64531/stats/round
# <Response [200]>
# Stored data for player 64531 in ../data/64531.json
# Processing Player with ID 64532
# requesting http://www.playlivemanager.com/api/players/64532/stats/round
# <Response [200]>
# Stored data for player 64532 in ../data/64532.json
# Processing Player with ID 64533
# requesting http://www.playlivemanager.com/api/players/64533/stats/round
# <Response [200]>
# Stored data for player 64533 in ../data/64533.json
# Processing Player with ID 64534
# requesting http://www.playlivemanager.com/api/players/64534/stats/round
# <Response [200]>
# Stored data for player 64534 in ../data/64534.json
# Processing Player with ID 64535
# requesting http://www.playlivemanager.com/api/players/64535/stats/round
# <Response [200]>
# Stored data for player 64535 in ../data/64535.json
# Processing Player with ID 64536
# requesting http://www.playlivemanager.com/api/players/64536/stats/round
# <Response [200]>
# Stored data for player 64536 in ../data/64536.json
# Processing Player with ID 64537
# requesting http://www.playlivemanager.com/api/players/64537/stats/round
# <Response [200]>
# Stored data for player 64537 in ../data/64537.json
# Processing Player with ID 64538
# requesting http://www.playlivemanager.com/api/players/64538/stats/round
# <Response [200]>
# Stored data for player 64538 in ../data/64538.json
# Processing Player with ID 64539
# requesting http://www.playlivemanager.com/api/players/64539/stats/round
# <Response [200]>
# Stored data for player 64539 in ../data/64539.json
# Processing Player with ID 64540
# requesting http://www.playlivemanager.com/api/players/64540/stats/round
# <Response [200]>
# Stored data for player 64540 in ../data/64540.json
# Processing Player with ID 64541
# requesting http://www.playlivemanager.com/api/players/64541/stats/round
# <Response [200]>
# Stored data for player 64541 in ../data/64541.json
# Processing Player with ID 64542
# requesting http://www.playlivemanager.com/api/players/64542/stats/round
# <Response [200]>
# Stored data for player 64542 in ../data/64542.json
# Processing Player with ID 64543
# requesting http://www.playlivemanager.com/api/players/64543/stats/round
# <Response [200]>
# Stored data for player 64543 in ../data/64543.json
# Processing Player with ID 64544
# requesting http://www.playlivemanager.com/api/players/64544/stats/round
# <Response [200]>
# Stored data for player 64544 in ../data/64544.json
# Processing Player with ID 64545
# requesting http://www.playlivemanager.com/api/players/64545/stats/round
# <Response [200]>
# Stored data for player 64545 in ../data/64545.json
# Processing Player with ID 64546
# requesting http://www.playlivemanager.com/api/players/64546/stats/round
# <Response [200]>
# Stored data for player 64546 in ../data/64546.json
# Processing Player with ID 64547
# requesting http://www.playlivemanager.com/api/players/64547/stats/round
# <Response [200]>
# Stored data for player 64547 in ../data/64547.json
# Processing Player with ID 64548
# requesting http://www.playlivemanager.com/api/players/64548/stats/round
# <Response [200]>
# Stored data for player 64548 in ../data/64548.json
# Processing Player with ID 64549
# requesting http://www.playlivemanager.com/api/players/64549/stats/round
# <Response [200]>
# Stored data for player 64549 in ../data/64549.json
# Processing Player with ID 64550
# requesting http://www.playlivemanager.com/api/players/64550/stats/round
# <Response [200]>
# Stored data for player 64550 in ../data/64550.json
# Processing Player with ID 64551
# requesting http://www.playlivemanager.com/api/players/64551/stats/round
# <Response [200]>
# Stored data for player 64551 in ../data/64551.json
# Processing Player with ID 64552
# requesting http://www.playlivemanager.com/api/players/64552/stats/round
# <Response [200]>
# Stored data for player 64552 in ../data/64552.json
# Processing Player with ID 64553
# requesting http://www.playlivemanager.com/api/players/64553/stats/round
# <Response [200]>
# Stored data for player 64553 in ../data/64553.json
# Processing Player with ID 64554
# requesting http://www.playlivemanager.com/api/players/64554/stats/round
# <Response [200]>
# Stored data for player 64554 in ../data/64554.json
# Processing Player with ID 64555
# requesting http://www.playlivemanager.com/api/players/64555/stats/round
# <Response [200]>
# Stored data for player 64555 in ../data/64555.json
# Processing Player with ID 64556
# requesting http://www.playlivemanager.com/api/players/64556/stats/round
# <Response [200]>
# Stored data for player 64556 in ../data/64556.json
# Processing Player with ID 64557
# requesting http://www.playlivemanager.com/api/players/64557/stats/round
# <Response [200]>
# Stored data for player 64557 in ../data/64557.json
# Processing Player with ID 64558
# requesting http://www.playlivemanager.com/api/players/64558/stats/round
# <Response [200]>
# Stored data for player 64558 in ../data/64558.json
# Processing Player with ID 64559
# requesting http://www.playlivemanager.com/api/players/64559/stats/round
# <Response [200]>
# Stored data for player 64559 in ../data/64559.json
# Processing Player with ID 64560
# requesting http://www.playlivemanager.com/api/players/64560/stats/round
# <Response [200]>
# Stored data for player 64560 in ../data/64560.json
# Processing Player with ID 64561
# requesting http://www.playlivemanager.com/api/players/64561/stats/round
# <Response [200]>
# Stored data for player 64561 in ../data/64561.json
# Processing Player with ID 64562
# requesting http://www.playlivemanager.com/api/players/64562/stats/round
# <Response [200]>
# Stored data for player 64562 in ../data/64562.json
# Processing Player with ID 64563
# requesting http://www.playlivemanager.com/api/players/64563/stats/round
# <Response [200]>
# Stored data for player 64563 in ../data/64563.json
# Processing Player with ID 64564
# requesting http://www.playlivemanager.com/api/players/64564/stats/round
# <Response [200]>
# Stored data for player 64564 in ../data/64564.json
# Processing Player with ID 64565
# requesting http://www.playlivemanager.com/api/players/64565/stats/round
# <Response [200]>
# Stored data for player 64565 in ../data/64565.json
# Processing Player with ID 64566
# requesting http://www.playlivemanager.com/api/players/64566/stats/round
# <Response [200]>
# Stored data for player 64566 in ../data/64566.json
# Processing Player with ID 64567
# requesting http://www.playlivemanager.com/api/players/64567/stats/round
# <Response [200]>
# Stored data for player 64567 in ../data/64567.json
# Processing Player with ID 64568
# requesting http://www.playlivemanager.com/api/players/64568/stats/round
# <Response [200]>
# Stored data for player 64568 in ../data/64568.json
# Processing Player with ID 64569
# requesting http://www.playlivemanager.com/api/players/64569/stats/round
# <Response [200]>
# Stored data for player 64569 in ../data/64569.json
# Processing Player with ID 64570
# requesting http://www.playlivemanager.com/api/players/64570/stats/round
# <Response [200]>
# Stored data for player 64570 in ../data/64570.json
# Processing Player with ID 64571
# requesting http://www.playlivemanager.com/api/players/64571/stats/round
# <Response [200]>
# Stored data for player 64571 in ../data/64571.json
# Processing Player with ID 64572
# requesting http://www.playlivemanager.com/api/players/64572/stats/round
# <Response [200]>
# Stored data for player 64572 in ../data/64572.json
# Processing Player with ID 64573
# requesting http://www.playlivemanager.com/api/players/64573/stats/round
# <Response [200]>
# Stored data for player 64573 in ../data/64573.json
# Processing Player with ID 64574
# requesting http://www.playlivemanager.com/api/players/64574/stats/round
# <Response [200]>
# Stored data for player 64574 in ../data/64574.json
# Processing Player with ID 64575
# requesting http://www.playlivemanager.com/api/players/64575/stats/round
# <Response [200]>
# Stored data for player 64575 in ../data/64575.json
# Processing Player with ID 64576
# requesting http://www.playlivemanager.com/api/players/64576/stats/round
# <Response [200]>
# Stored data for player 64576 in ../data/64576.json
# Processing Player with ID 64577
# requesting http://www.playlivemanager.com/api/players/64577/stats/round
# <Response [200]>
# Stored data for player 64577 in ../data/64577.json
# Processing Player with ID 64578
# requesting http://www.playlivemanager.com/api/players/64578/stats/round
# <Response [200]>
# Stored data for player 64578 in ../data/64578.json
# Processing Player with ID 64579
# requesting http://www.playlivemanager.com/api/players/64579/stats/round
# <Response [200]>
# Stored data for player 64579 in ../data/64579.json
# Processing Player with ID 64580
# requesting http://www.playlivemanager.com/api/players/64580/stats/round
# <Response [200]>
# Stored data for player 64580 in ../data/64580.json
# Processing Player with ID 64581
# requesting http://www.playlivemanager.com/api/players/64581/stats/round
# <Response [200]>
# Stored data for player 64581 in ../data/64581.json
# Processing Player with ID 64582
# requesting http://www.playlivemanager.com/api/players/64582/stats/round
# <Response [200]>
# Stored data for player 64582 in ../data/64582.json
# Processing Player with ID 64583
# requesting http://www.playlivemanager.com/api/players/64583/stats/round
# <Response [200]>
# Stored data for player 64583 in ../data/64583.json
# Processing Player with ID 64584
# requesting http://www.playlivemanager.com/api/players/64584/stats/round
# <Response [200]>
# Stored data for player 64584 in ../data/64584.json
# Processing Player with ID 64585
# requesting http://www.playlivemanager.com/api/players/64585/stats/round
# <Response [200]>
# Stored data for player 64585 in ../data/64585.json
# Processing Player with ID 64586
# requesting http://www.playlivemanager.com/api/players/64586/stats/round
# <Response [200]>
# Stored data for player 64586 in ../data/64586.json
# Processing Player with ID 64587
# requesting http://www.playlivemanager.com/api/players/64587/stats/round
# <Response [200]>
# Stored data for player 64587 in ../data/64587.json
# Processing Player with ID 64588
# requesting http://www.playlivemanager.com/api/players/64588/stats/round
# <Response [200]>
# Stored data for player 64588 in ../data/64588.json
# Processing Player with ID 64589
# requesting http://www.playlivemanager.com/api/players/64589/stats/round
# <Response [200]>
# Stored data for player 64589 in ../data/64589.json
# Processing Player with ID 64590
# requesting http://www.playlivemanager.com/api/players/64590/stats/round
# <Response [200]>
# Stored data for player 64590 in ../data/64590.json
# Processing Player with ID 64591
# requesting http://www.playlivemanager.com/api/players/64591/stats/round
# <Response [200]>
# Stored data for player 64591 in ../data/64591.json
# Processing Player with ID 64592
# requesting http://www.playlivemanager.com/api/players/64592/stats/round
# <Response [200]>
# Stored data for player 64592 in ../data/64592.json
# Processing Player with ID 64593
# requesting http://www.playlivemanager.com/api/players/64593/stats/round
# <Response [200]>
# Stored data for player 64593 in ../data/64593.json
# Processing Player with ID 64594
# requesting http://www.playlivemanager.com/api/players/64594/stats/round
# <Response [200]>
# Stored data for player 64594 in ../data/64594.json
# Processing Player with ID 64595
# requesting http://www.playlivemanager.com/api/players/64595/stats/round
# <Response [200]>
# Stored data for player 64595 in ../data/64595.json
# Processing Player with ID 64596
# requesting http://www.playlivemanager.com/api/players/64596/stats/round
# <Response [200]>
# Stored data for player 64596 in ../data/64596.json
# Processing Player with ID 64597
# requesting http://www.playlivemanager.com/api/players/64597/stats/round
# <Response [200]>
# Stored data for player 64597 in ../data/64597.json
# Processing Player with ID 64598
# requesting http://www.playlivemanager.com/api/players/64598/stats/round
# <Response [200]>
# Stored data for player 64598 in ../data/64598.json
# Processing Player with ID 64599
# requesting http://www.playlivemanager.com/api/players/64599/stats/round
# <Response [200]>
# Stored data for player 64599 in ../data/64599.json
# Processing Player with ID 64600
# requesting http://www.playlivemanager.com/api/players/64600/stats/round
# <Response [200]>
# Stored data for player 64600 in ../data/64600.json
# Processing Player with ID 64601
# requesting http://www.playlivemanager.com/api/players/64601/stats/round
# <Response [200]>
# Stored data for player 64601 in ../data/64601.json
# Processing Player with ID 64602
# requesting http://www.playlivemanager.com/api/players/64602/stats/round
# <Response [200]>
# Stored data for player 64602 in ../data/64602.json
# Processing Player with ID 64603
# requesting http://www.playlivemanager.com/api/players/64603/stats/round
# <Response [200]>
# Stored data for player 64603 in ../data/64603.json
# Processing Player with ID 64604
# requesting http://www.playlivemanager.com/api/players/64604/stats/round
# <Response [200]>
# Stored data for player 64604 in ../data/64604.json
# Processing Player with ID 64605
# requesting http://www.playlivemanager.com/api/players/64605/stats/round
# <Response [200]>
# Stored data for player 64605 in ../data/64605.json
# Processing Player with ID 64606
# requesting http://www.playlivemanager.com/api/players/64606/stats/round
# <Response [200]>
# Stored data for player 64606 in ../data/64606.json
# Processing Player with ID 64607
# requesting http://www.playlivemanager.com/api/players/64607/stats/round
# <Response [200]>
# Stored data for player 64607 in ../data/64607.json
# Processing Player with ID 64608
# requesting http://www.playlivemanager.com/api/players/64608/stats/round
# <Response [200]>
# Stored data for player 64608 in ../data/64608.json
# Processing Player with ID 64609
# requesting http://www.playlivemanager.com/api/players/64609/stats/round
# <Response [200]>
# Stored data for player 64609 in ../data/64609.json
# Processing Player with ID 64610
# requesting http://www.playlivemanager.com/api/players/64610/stats/round
# <Response [200]>
# Stored data for player 64610 in ../data/64610.json
# Processing Player with ID 64611
# requesting http://www.playlivemanager.com/api/players/64611/stats/round
# <Response [200]>
# Stored data for player 64611 in ../data/64611.json
# Processing Player with ID 64612
# requesting http://www.playlivemanager.com/api/players/64612/stats/round
# <Response [200]>
# Stored data for player 64612 in ../data/64612.json
# Processing Player with ID 64613
# requesting http://www.playlivemanager.com/api/players/64613/stats/round
# <Response [200]>
# Stored data for player 64613 in ../data/64613.json
# Processing Player with ID 64614
# requesting http://www.playlivemanager.com/api/players/64614/stats/round
# <Response [200]>
# Stored data for player 64614 in ../data/64614.json
# Processing Player with ID 64615
# requesting http://www.playlivemanager.com/api/players/64615/stats/round
# <Response [200]>
# Stored data for player 64615 in ../data/64615.json
# Processing Player with ID 64616
# requesting http://www.playlivemanager.com/api/players/64616/stats/round
# <Response [200]>
# Stored data for player 64616 in ../data/64616.json
# Processing Player with ID 64617
# requesting http://www.playlivemanager.com/api/players/64617/stats/round
# <Response [200]>
# Stored data for player 64617 in ../data/64617.json
# Processing Player with ID 64618
# requesting http://www.playlivemanager.com/api/players/64618/stats/round
# <Response [200]>
# Stored data for player 64618 in ../data/64618.json
# Processing Player with ID 64619
# requesting http://www.playlivemanager.com/api/players/64619/stats/round
# <Response [200]>
# Stored data for player 64619 in ../data/64619.json
# Processing Player with ID 64620
# requesting http://www.playlivemanager.com/api/players/64620/stats/round
# <Response [200]>
# Stored data for player 64620 in ../data/64620.json
# Processing Player with ID 64621
# requesting http://www.playlivemanager.com/api/players/64621/stats/round
# <Response [200]>
# Stored data for player 64621 in ../data/64621.json
# Processing Player with ID 64622
# requesting http://www.playlivemanager.com/api/players/64622/stats/round
# <Response [200]>
# Stored data for player 64622 in ../data/64622.json
# Processing Player with ID 64623
# requesting http://www.playlivemanager.com/api/players/64623/stats/round
# <Response [200]>
# Stored data for player 64623 in ../data/64623.json
# Processing Player with ID 64624
# requesting http://www.playlivemanager.com/api/players/64624/stats/round
# <Response [200]>
# Stored data for player 64624 in ../data/64624.json
# Processing Player with ID 64625
# requesting http://www.playlivemanager.com/api/players/64625/stats/round
# <Response [200]>
# Stored data for player 64625 in ../data/64625.json
# Processing Player with ID 64626
# requesting http://www.playlivemanager.com/api/players/64626/stats/round
# <Response [200]>
# Stored data for player 64626 in ../data/64626.json
# Processing Player with ID 64627
# requesting http://www.playlivemanager.com/api/players/64627/stats/round
# <Response [200]>
# Stored data for player 64627 in ../data/64627.json
# Processing Player with ID 64628
# requesting http://www.playlivemanager.com/api/players/64628/stats/round
# <Response [200]>
# Stored data for player 64628 in ../data/64628.json
# Processing Player with ID 64629
# requesting http://www.playlivemanager.com/api/players/64629/stats/round
# <Response [200]>
# Stored data for player 64629 in ../data/64629.json
# Processing Player with ID 64630
# requesting http://www.playlivemanager.com/api/players/64630/stats/round
# <Response [200]>
# Stored data for player 64630 in ../data/64630.json
# Processing Player with ID 64631
# requesting http://www.playlivemanager.com/api/players/64631/stats/round
# <Response [200]>
# Stored data for player 64631 in ../data/64631.json
# Processing Player with ID 64632
# requesting http://www.playlivemanager.com/api/players/64632/stats/round
# <Response [200]>
# Stored data for player 64632 in ../data/64632.json
# Processing Player with ID 64633
# requesting http://www.playlivemanager.com/api/players/64633/stats/round
# <Response [200]>
# Stored data for player 64633 in ../data/64633.json
# Processing Player with ID 64634
# requesting http://www.playlivemanager.com/api/players/64634/stats/round
# <Response [200]>
# Stored data for player 64634 in ../data/64634.json
# Processing Player with ID 64635
# requesting http://www.playlivemanager.com/api/players/64635/stats/round
# <Response [200]>
# Stored data for player 64635 in ../data/64635.json
# Processing Player with ID 64636
# requesting http://www.playlivemanager.com/api/players/64636/stats/round
# <Response [200]>
# Stored data for player 64636 in ../data/64636.json
# Processing Player with ID 64637
# requesting http://www.playlivemanager.com/api/players/64637/stats/round
# <Response [200]>
# Stored data for player 64637 in ../data/64637.json
# Processing Player with ID 64638
# requesting http://www.playlivemanager.com/api/players/64638/stats/round
# <Response [200]>
# Stored data for player 64638 in ../data/64638.json
# Processing Player with ID 64639
# requesting http://www.playlivemanager.com/api/players/64639/stats/round
# <Response [200]>
# Stored data for player 64639 in ../data/64639.json
# Processing Player with ID 64640
# requesting http://www.playlivemanager.com/api/players/64640/stats/round
# <Response [200]>
# Stored data for player 64640 in ../data/64640.json
# Processing Player with ID 64641
# requesting http://www.playlivemanager.com/api/players/64641/stats/round
# <Response [200]>
# Stored data for player 64641 in ../data/64641.json
# Processing Player with ID 64642
# requesting http://www.playlivemanager.com/api/players/64642/stats/round
# <Response [200]>
# Stored data for player 64642 in ../data/64642.json
# Processing Player with ID 64643
# requesting http://www.playlivemanager.com/api/players/64643/stats/round
# <Response [200]>
# Stored data for player 64643 in ../data/64643.json
# Processing Player with ID 64644
# requesting http://www.playlivemanager.com/api/players/64644/stats/round
# <Response [200]>
# Stored data for player 64644 in ../data/64644.json
# Processing Player with ID 64645
# requesting http://www.playlivemanager.com/api/players/64645/stats/round
# <Response [200]>
# Stored data for player 64645 in ../data/64645.json
# Processing Player with ID 64646
# requesting http://www.playlivemanager.com/api/players/64646/stats/round
# <Response [200]>
# Stored data for player 64646 in ../data/64646.json
# Processing Player with ID 64647
# requesting http://www.playlivemanager.com/api/players/64647/stats/round
# <Response [200]>
# Stored data for player 64647 in ../data/64647.json
# Processing Player with ID 64648
# requesting http://www.playlivemanager.com/api/players/64648/stats/round
# <Response [200]>
# Stored data for player 64648 in ../data/64648.json
# Processing Player with ID 64649
# requesting http://www.playlivemanager.com/api/players/64649/stats/round
# <Response [200]>
# Stored data for player 64649 in ../data/64649.json
# Processing Player with ID 64650
# requesting http://www.playlivemanager.com/api/players/64650/stats/round
# <Response [200]>
# Stored data for player 64650 in ../data/64650.json
# Processing Player with ID 64651
# requesting http://www.playlivemanager.com/api/players/64651/stats/round
# <Response [200]>
# Stored data for player 64651 in ../data/64651.json
# Processing Player with ID 64652
# requesting http://www.playlivemanager.com/api/players/64652/stats/round
# <Response [200]>
# Stored data for player 64652 in ../data/64652.json
# Processing Player with ID 64653
# requesting http://www.playlivemanager.com/api/players/64653/stats/round
# <Response [200]>
# Stored data for player 64653 in ../data/64653.json
# Processing Player with ID 64654
# requesting http://www.playlivemanager.com/api/players/64654/stats/round
# <Response [200]>
# Stored data for player 64654 in ../data/64654.json
# Processing Player with ID 64655
# requesting http://www.playlivemanager.com/api/players/64655/stats/round
# <Response [200]>
# Stored data for player 64655 in ../data/64655.json
# Processing Player with ID 64656
# requesting http://www.playlivemanager.com/api/players/64656/stats/round
# <Response [200]>
# Stored data for player 64656 in ../data/64656.json
# Processing Player with ID 64657
# requesting http://www.playlivemanager.com/api/players/64657/stats/round
# <Response [200]>
# Stored data for player 64657 in ../data/64657.json
# Processing Player with ID 64658
# requesting http://www.playlivemanager.com/api/players/64658/stats/round
# <Response [200]>
# Stored data for player 64658 in ../data/64658.json
# Processing Player with ID 64659
# requesting http://www.playlivemanager.com/api/players/64659/stats/round
# <Response [200]>
# Stored data for player 64659 in ../data/64659.json
# Processing Player with ID 64660
# requesting http://www.playlivemanager.com/api/players/64660/stats/round
# <Response [200]>
# Stored data for player 64660 in ../data/64660.json
# Processing Player with ID 64661
# requesting http://www.playlivemanager.com/api/players/64661/stats/round
# <Response [200]>
# Stored data for player 64661 in ../data/64661.json
# Processing Player with ID 64662
# requesting http://www.playlivemanager.com/api/players/64662/stats/round
# <Response [200]>
# Stored data for player 64662 in ../data/64662.json
# Processing Player with ID 64663
# requesting http://www.playlivemanager.com/api/players/64663/stats/round
# <Response [200]>
# Stored data for player 64663 in ../data/64663.json
# Processing Player with ID 64664
# requesting http://www.playlivemanager.com/api/players/64664/stats/round
# <Response [200]>
# Stored data for player 64664 in ../data/64664.json
# Processing Player with ID 64665
# requesting http://www.playlivemanager.com/api/players/64665/stats/round
# <Response [200]>
# Stored data for player 64665 in ../data/64665.json
# Processing Player with ID 64666
# requesting http://www.playlivemanager.com/api/players/64666/stats/round
# <Response [200]>
# Stored data for player 64666 in ../data/64666.json
# Processing Player with ID 64667
# requesting http://www.playlivemanager.com/api/players/64667/stats/round
# <Response [200]>
# Stored data for player 64667 in ../data/64667.json
# Processing Player with ID 64668
# requesting http://www.playlivemanager.com/api/players/64668/stats/round
# <Response [200]>
# Stored data for player 64668 in ../data/64668.json
# Processing Player with ID 64669
# requesting http://www.playlivemanager.com/api/players/64669/stats/round
# <Response [200]>
# Stored data for player 64669 in ../data/64669.json
# Processing Player with ID 64670
# requesting http://www.playlivemanager.com/api/players/64670/stats/round
# <Response [200]>
# Stored data for player 64670 in ../data/64670.json
# Processing Player with ID 64671
# requesting http://www.playlivemanager.com/api/players/64671/stats/round
# <Response [200]>
# Stored data for player 64671 in ../data/64671.json
# Processing Player with ID 64672
# requesting http://www.playlivemanager.com/api/players/64672/stats/round
# <Response [200]>
# Stored data for player 64672 in ../data/64672.json
# Processing Player with ID 64673
# requesting http://www.playlivemanager.com/api/players/64673/stats/round
# <Response [200]>
# Stored data for player 64673 in ../data/64673.json
# Processing Player with ID 64674
# requesting http://www.playlivemanager.com/api/players/64674/stats/round
# <Response [200]>
# Stored data for player 64674 in ../data/64674.json
# Processing Player with ID 64675
# requesting http://www.playlivemanager.com/api/players/64675/stats/round
# <Response [200]>
# Stored data for player 64675 in ../data/64675.json
# Processing Player with ID 64676
# requesting http://www.playlivemanager.com/api/players/64676/stats/round
# <Response [200]>
# Stored data for player 64676 in ../data/64676.json
# Processing Player with ID 64677
# requesting http://www.playlivemanager.com/api/players/64677/stats/round
# <Response [200]>
# Stored data for player 64677 in ../data/64677.json
# Processing Player with ID 64678
# requesting http://www.playlivemanager.com/api/players/64678/stats/round
# <Response [200]>
# Stored data for player 64678 in ../data/64678.json
# ...
# Processing Player with ID 66707
# requesting http://www.playlivemanager.com/api/players/66707/stats/round
# <Response [200]>
# Stored data for player 66707 in ../data/66707.json
# Processing Player with ID 66708
# requesting http://www.playlivemanager.com/api/players/66708/stats/round
# <Response [200]>
# Stored data for player 66708 in ../data/66708.json
# Processing Player with ID 66709
# requesting http://www.playlivemanager.com/api/players/66709/stats/round
# <Response [200]>
# Stored data for player 66709 in ../data/66709.json
# Processing Player with ID 66710
# requesting http://www.playlivemanager.com/api/players/66710/stats/round
# <Response [200]>
# Stored data for player 66710 in ../data/66710.json
# Processing Player with ID 66711
# requesting http://www.playlivemanager.com/api/players/66711/stats/round
# <Response [200]>
# Stored data for player 66711 in ../data/66711.json
# Processing Player with ID 66712
# requesting http://www.playlivemanager.com/api/players/66712/stats/round
# <Response [200]>
# Stored data for player 66712 in ../data/66712.json
# Processing Player with ID 66713
# requesting http://www.playlivemanager.com/api/players/66713/stats/round
# <Response [200]>
# Stored data for player 66713 in ../data/66713.json
# Processing Player with ID 66714
# requesting http://www.playlivemanager.com/api/players/66714/stats/round
# <Response [200]>
# Stored data for player 66714 in ../data/66714.json
# Processing Player with ID 66715
# requesting http://www.playlivemanager.com/api/players/66715/stats/round
# <Response [200]>
# Stored data for player 66715 in ../data/66715.json
# Processing Player with ID 66716
# requesting http://www.playlivemanager.com/api/players/66716/stats/round
# <Response [200]>
# Stored data for player 66716 in ../data/66716.json
# Processing Player with ID 66717
# requesting http://www.playlivemanager.com/api/players/66717/stats/round
# <Response [200]>
# Stored data for player 66717 in ../data/66717.json
# Processing Player with ID 66718
# requesting http://www.playlivemanager.com/api/players/66718/stats/round
# <Response [200]>
# Stored data for player 66718 in ../data/66718.json
# Processing Player with ID 66719
# requesting http://www.playlivemanager.com/api/players/66719/stats/round
# <Response [200]>
# Stored data for player 66719 in ../data/66719.json
# Processing Player with ID 66720
# requesting http://www.playlivemanager.com/api/players/66720/stats/round
# <Response [200]>
# Stored data for player 66720 in ../data/66720.json
# Processing Player with ID 66721
# requesting http://www.playlivemanager.com/api/players/66721/stats/round
# <Response [200]>
# Stored data for player 66721 in ../data/66721.json
# Processing Player with ID 66722
# requesting http://www.playlivemanager.com/api/players/66722/stats/round
# <Response [200]>
# Stored data for player 66722 in ../data/66722.json
# Processing Player with ID 66723
# requesting http://www.playlivemanager.com/api/players/66723/stats/round
# <Response [200]>
# Stored data for player 66723 in ../data/66723.json
# Processing Player with ID 66724
# requesting http://www.playlivemanager.com/api/players/66724/stats/round
# <Response [200]>
# Stored data for player 66724 in ../data/66724.json
# Processing Player with ID 66725
# requesting http://www.playlivemanager.com/api/players/66725/stats/round
# <Response [200]>
# Stored data for player 66725 in ../data/66725.json
# Processing Player with ID 66726
# requesting http://www.playlivemanager.com/api/players/66726/stats/round
# <Response [200]>
# Stored data for player 66726 in ../data/66726.json
# Processing Player with ID 66727
# requesting http://www.playlivemanager.com/api/players/66727/stats/round
# <Response [200]>
# Stored data for player 66727 in ../data/66727.json
# Processing Player with ID 66728
# requesting http://www.playlivemanager.com/api/players/66728/stats/round
# <Response [200]>
# Stored data for player 66728 in ../data/66728.json
# Processing Player with ID 66729
# requesting http://www.playlivemanager.com/api/players/66729/stats/round
# <Response [200]>
# Stored data for player 66729 in ../data/66729.json
# Processing Player with ID 66730
# requesting http://www.playlivemanager.com/api/players/66730/stats/round
# <Response [200]>
# Stored data for player 66730 in ../data/66730.json
# Processing Player with ID 66731
# requesting http://www.playlivemanager.com/api/players/66731/stats/round
# <Response [200]>
# Stored data for player 66731 in ../data/66731.json
# Processing Player with ID 66732
# requesting http://www.playlivemanager.com/api/players/66732/stats/round
# <Response [200]>
# Stored data for player 66732 in ../data/66732.json
# Processing Player with ID 66733
# requesting http://www.playlivemanager.com/api/players/66733/stats/round
# <Response [200]>
# Stored data for player 66733 in ../data/66733.json
# Processing Player with ID 66734
# requesting http://www.playlivemanager.com/api/players/66734/stats/round
# <Response [200]>
# Stored data for player 66734 in ../data/66734.json
# Processing Player with ID 66735
# requesting http://www.playlivemanager.com/api/players/66735/stats/round
# <Response [200]>
# Stored data for player 66735 in ../data/66735.json
# Processing Player with ID 66736
# requesting http://www.playlivemanager.com/api/players/66736/stats/round
# <Response [200]>
# Stored data for player 66736 in ../data/66736.json
# Processing Player with ID 66737
# requesting http://www.playlivemanager.com/api/players/66737/stats/round
# <Response [200]>
# Stored data for player 66737 in ../data/66737.json
# Processing Player with ID 66738
# requesting http://www.playlivemanager.com/api/players/66738/stats/round
# <Response [200]>
# Stored data for player 66738 in ../data/66738.json
# Processing Player with ID 66739
# requesting http://www.playlivemanager.com/api/players/66739/stats/round
# <Response [200]>
# Stored data for player 66739 in ../data/66739.json
# Processing Player with ID 66740
# requesting http://www.playlivemanager.com/api/players/66740/stats/round
# <Response [200]>
# Stored data for player 66740 in ../data/66740.json
# Processing Player with ID 66741
# requesting http://www.playlivemanager.com/api/players/66741/stats/round
# <Response [200]>
# Stored data for player 66741 in ../data/66741.json
# Processing Player with ID 66742
# requesting http://www.playlivemanager.com/api/players/66742/stats/round
# <Response [200]>
# Stored data for player 66742 in ../data/66742.json
# Processing Player with ID 66743
# requesting http://www.playlivemanager.com/api/players/66743/stats/round
# <Response [200]>
# Stored data for player 66743 in ../data/66743.json
# Processing Player with ID 66744
# requesting http://www.playlivemanager.com/api/players/66744/stats/round
# <Response [200]>
# Stored data for player 66744 in ../data/66744.json
# Processing Player with ID 66745
# requesting http://www.playlivemanager.com/api/players/66745/stats/round
# <Response [200]>
# Stored data for player 66745 in ../data/66745.json
# Processing Player with ID 66746
# requesting http://www.playlivemanager.com/api/players/66746/stats/round
# <Response [200]>
# Stored data for player 66746 in ../data/66746.json
# Processing Player with ID 66747
# requesting http://www.playlivemanager.com/api/players/66747/stats/round
# <Response [200]>
# Stored data for player 66747 in ../data/66747.json
# Processing Player with ID 66748
# requesting http://www.playlivemanager.com/api/players/66748/stats/round
# <Response [200]>
# Stored data for player 66748 in ../data/66748.json
# Processing Player with ID 66749
# requesting http://www.playlivemanager.com/api/players/66749/stats/round
# <Response [200]>
# Stored data for player 66749 in ../data/66749.json
# Processing Player with ID 66750
# requesting http://www.playlivemanager.com/api/players/66750/stats/round
# <Response [200]>
# Stored data for player 66750 in ../data/66750.json
# Processing Player with ID 66751
# requesting http://www.playlivemanager.com/api/players/66751/stats/round
# <Response [200]>
# Stored data for player 66751 in ../data/66751.json
# Processing Player with ID 66752
# requesting http://www.playlivemanager.com/api/players/66752/stats/round
# <Response [200]>
# Stored data for player 66752 in ../data/66752.json
# Processing Player with ID 66753
# requesting http://www.playlivemanager.com/api/players/66753/stats/round
# <Response [200]>
# Stored data for player 66753 in ../data/66753.json
# Processing Player with ID 66754
# requesting http://www.playlivemanager.com/api/players/66754/stats/round
# <Response [200]>
# Stored data for player 66754 in ../data/66754.json
# Processing Player with ID 66755
# requesting http://www.playlivemanager.com/api/players/66755/stats/round
# <Response [200]>
# Stored data for player 66755 in ../data/66755.json
# Processing Player with ID 66756
# requesting http://www.playlivemanager.com/api/players/66756/stats/round
# <Response [200]>
# Stored data for player 66756 in ../data/66756.json
# Processing Player with ID 66757
# requesting http://www.playlivemanager.com/api/players/66757/stats/round
# <Response [200]>
# Stored data for player 66757 in ../data/66757.json
# Processing Player with ID 66758
# requesting http://www.playlivemanager.com/api/players/66758/stats/round
# <Response [200]>
# Stored data for player 66758 in ../data/66758.json
# Processing Player with ID 66759
# requesting http://www.playlivemanager.com/api/players/66759/stats/round
# <Response [200]>
# Stored data for player 66759 in ../data/66759.json
# Processing Player with ID 66760
# requesting http://www.playlivemanager.com/api/players/66760/stats/round
# <Response [200]>
# Stored data for player 66760 in ../data/66760.json
# Processing Player with ID 66761
# requesting http://www.playlivemanager.com/api/players/66761/stats/round
# <Response [200]>
# Stored data for player 66761 in ../data/66761.json
# Processing Player with ID 66762
# requesting http://www.playlivemanager.com/api/players/66762/stats/round
# <Response [200]>
# Stored data for player 66762 in ../data/66762.json
# Processing Player with ID 66763
# requesting http://www.playlivemanager.com/api/players/66763/stats/round
# <Response [200]>
# Stored data for player 66763 in ../data/66763.json
# Processing Player with ID 66764
# requesting http://www.playlivemanager.com/api/players/66764/stats/round
# <Response [200]>
# Stored data for player 66764 in ../data/66764.json
# Processing Player with ID 66765
# requesting http://www.playlivemanager.com/api/players/66765/stats/round
# <Response [200]>
# Stored data for player 66765 in ../data/66765.json
# Processing Player with ID 66766
# requesting http://www.playlivemanager.com/api/players/66766/stats/round
# <Response [200]>
# Stored data for player 66766 in ../data/66766.json
# Processing Player with ID 66767
# requesting http://www.playlivemanager.com/api/players/66767/stats/round
# <Response [200]>
# Stored data for player 66767 in ../data/66767.json
# Processing Player with ID 66768
# requesting http://www.playlivemanager.com/api/players/66768/stats/round
# <Response [200]>
# Stored data for player 66768 in ../data/66768.json
# Processing Player with ID 66769
# requesting http://www.playlivemanager.com/api/players/66769/stats/round
# <Response [200]>
# Stored data for player 66769 in ../data/66769.json
# Processing Player with ID 66770
# requesting http://www.playlivemanager.com/api/players/66770/stats/round
# <Response [200]>
# Stored data for player 66770 in ../data/66770.json
# Processing Player with ID 66771
# requesting http://www.playlivemanager.com/api/players/66771/stats/round
# <Response [200]>
# Stored data for player 66771 in ../data/66771.json
# Processing Player with ID 66772
# requesting http://www.playlivemanager.com/api/players/66772/stats/round
# <Response [200]>
# Stored data for player 66772 in ../data/66772.json
# Processing Player with ID 66773
# requesting http://www.playlivemanager.com/api/players/66773/stats/round
# <Response [200]>
# Stored data for player 66773 in ../data/66773.json
# Processing Player with ID 66774
# requesting http://www.playlivemanager.com/api/players/66774/stats/round
# <Response [200]>
# Stored data for player 66774 in ../data/66774.json
# Processing Player with ID 66775
# requesting http://www.playlivemanager.com/api/players/66775/stats/round
# <Response [200]>
# Stored data for player 66775 in ../data/66775.json
# Processing Player with ID 66776
# requesting http://www.playlivemanager.com/api/players/66776/stats/round
# <Response [200]>
# Stored data for player 66776 in ../data/66776.json
# Processing Player with ID 66777
# requesting http://www.playlivemanager.com/api/players/66777/stats/round
# <Response [200]>
# Stored data for player 66777 in ../data/66777.json
# Processing Player with ID 66778
# requesting http://www.playlivemanager.com/api/players/66778/stats/round
# <Response [200]>
# Stored data for player 66778 in ../data/66778.json
# Processing Player with ID 66779
# requesting http://www.playlivemanager.com/api/players/66779/stats/round
# <Response [200]>
# Stored data for player 66779 in ../data/66779.json
# Processing Player with ID 66780
# requesting http://www.playlivemanager.com/api/players/66780/stats/round
# <Response [200]>
# Stored data for player 66780 in ../data/66780.json
# Processing Player with ID 66781
# requesting http://www.playlivemanager.com/api/players/66781/stats/round
# <Response [200]>
# Stored data for player 66781 in ../data/66781.json
# Processing Player with ID 66782
# requesting http://www.playlivemanager.com/api/players/66782/stats/round
# <Response [200]>
# Stored data for player 66782 in ../data/66782.json
# Processing Player with ID 66783
# requesting http://www.playlivemanager.com/api/players/66783/stats/round
# <Response [200]>
# Stored data for player 66783 in ../data/66783.json
# Processing Player with ID 66784
# requesting http://www.playlivemanager.com/api/players/66784/stats/round
# <Response [200]>
# Stored data for player 66784 in ../data/66784.json
# Processing Player with ID 66785
# requesting http://www.playlivemanager.com/api/players/66785/stats/round
# <Response [200]>
# Stored data for player 66785 in ../data/66785.json
# Processing Player with ID 66786
# requesting http://www.playlivemanager.com/api/players/66786/stats/round
# <Response [200]>
# Stored data for player 66786 in ../data/66786.json
# Processing Player with ID 66787
# requesting http://www.playlivemanager.com/api/players/66787/stats/round
# <Response [200]>
# Stored data for player 66787 in ../data/66787.json
# Processing Player with ID 66788
# requesting http://www.playlivemanager.com/api/players/66788/stats/round
# <Response [200]>
# Stored data for player 66788 in ../data/66788.json
# Processing Player with ID 66789
# requesting http://www.playlivemanager.com/api/players/66789/stats/round
# <Response [200]>
# Stored data for player 66789 in ../data/66789.json
# Processing Player with ID 66790
# requesting http://www.playlivemanager.com/api/players/66790/stats/round
# <Response [200]>
# Stored data for player 66790 in ../data/66790.json
# Processing Player with ID 66791
# requesting http://www.playlivemanager.com/api/players/66791/stats/round
# <Response [200]>
# Stored data for player 66791 in ../data/66791.json
# Processing Player with ID 66792
# requesting http://www.playlivemanager.com/api/players/66792/stats/round
# <Response [200]>
# Stored data for player 66792 in ../data/66792.json
# Processing Player with ID 66793
# requesting http://www.playlivemanager.com/api/players/66793/stats/round
# <Response [200]>
# Stored data for player 66793 in ../data/66793.json
# Processing Player with ID 66794
# requesting http://www.playlivemanager.com/api/players/66794/stats/round
# <Response [200]>
# Stored data for player 66794 in ../data/66794.json
# Processing Player with ID 66795
# requesting http://www.playlivemanager.com/api/players/66795/stats/round
# <Response [200]>
# Stored data for player 66795 in ../data/66795.json
# Processing Player with ID 66796
# requesting http://www.playlivemanager.com/api/players/66796/stats/round
# <Response [200]>
# Stored data for player 66796 in ../data/66796.json
# Processing Player with ID 66797
# requesting http://www.playlivemanager.com/api/players/66797/stats/round
# <Response [200]>
# Stored data for player 66797 in ../data/66797.json
# Processing Player with ID 66798
# requesting http://www.playlivemanager.com/api/players/66798/stats/round
# <Response [200]>
# Stored data for player 66798 in ../data/66798.json
# Processing Player with ID 66799
# requesting http://www.playlivemanager.com/api/players/66799/stats/round
# <Response [200]>
# Stored data for player 66799 in ../data/66799.json

# %%
transform_data()
# Out:
# Deleting old files
# Begin transforming data
# Processing ../data/64400.json
# Added ../data/64400.json to ../data/all.json
# Processing ../data/64401.json
# Added ../data/64401.json to ../data/all.json
# Processing ../data/64402.json
# Added ../data/64402.json to ../data/all.json
# Processing ../data/64403.json
# Added ../data/64403.json to ../data/all.json
# Processing ../data/64404.json
# Added ../data/64404.json to ../data/all.json
# Processing ../data/64405.json
# Added ../data/64405.json to ../data/all.json
# Processing ../data/64406.json
# Added ../data/64406.json to ../data/all.json
# Processing ../data/64407.json
# Added ../data/64407.json to ../data/all.json
# Processing ../data/64408.json
# Added ../data/64408.json to ../data/all.json
# Processing ../data/64409.json
# Added ../data/64409.json to ../data/all.json
# Processing ../data/64410.json
# Added ../data/64410.json to ../data/all.json
# Processing ../data/64411.json
# Added ../data/64411.json to ../data/all.json
# Processing ../data/64412.json
# Added ../data/64412.json to ../data/all.json
# Processing ../data/64413.json
# Added ../data/64413.json to ../data/all.json
# Processing ../data/64414.json
# Added ../data/64414.json to ../data/all.json
# Processing ../data/64415.json
# Added ../data/64415.json to ../data/all.json
# Processing ../data/64416.json
# Added ../data/64416.json to ../data/all.json
# Processing ../data/64417.json
# Added ../data/64417.json to ../data/all.json
# Processing ../data/64418.json
# Added ../data/64418.json to ../data/all.json
# Processing ../data/64419.json
# Added ../data/64419.json to ../data/all.json
# Processing ../data/64420.json
# Added ../data/64420.json to ../data/all.json
# Processing ../data/64421.json
# Added ../data/64421.json to ../data/all.json
# Processing ../data/64422.json
# Added ../data/64422.json to ../data/all.json
# Processing ../data/64423.json
# Added ../data/64423.json to ../data/all.json
# Processing ../data/64424.json
# Added ../data/64424.json to ../data/all.json
# Processing ../data/64425.json
# Added ../data/64425.json to ../data/all.json
# Processing ../data/64426.json
# Added ../data/64426.json to ../data/all.json
# Processing ../data/64427.json
# Added ../data/64427.json to ../data/all.json
# Processing ../data/64428.json
# Added ../data/64428.json to ../data/all.json
# Processing ../data/64429.json
# Added ../data/64429.json to ../data/all.json
# Processing ../data/64430.json
# Added ../data/64430.json to ../data/all.json
# Processing ../data/64431.json
# Added ../data/64431.json to ../data/all.json
# Processing ../data/64432.json
# Added ../data/64432.json to ../data/all.json
# Processing ../data/64433.json
# Added ../data/64433.json to ../data/all.json
# Processing ../data/64434.json
# Added ../data/64434.json to ../data/all.json
# Processing ../data/64435.json
# Added ../data/64435.json to ../data/all.json
# Processing ../data/64436.json
# Added ../data/64436.json to ../data/all.json
# Processing ../data/64437.json
# Added ../data/64437.json to ../data/all.json
# Processing ../data/64438.json
# Added ../data/64438.json to ../data/all.json
# Processing ../data/64439.json
# Added ../data/64439.json to ../data/all.json
# Processing ../data/64440.json
# Added ../data/64440.json to ../data/all.json
# Processing ../data/64441.json
# Added ../data/64441.json to ../data/all.json
# Processing ../data/64442.json
# Added ../data/64442.json to ../data/all.json
# Processing ../data/64443.json
# Added ../data/64443.json to ../data/all.json
# Processing ../data/64444.json
# Added ../data/64444.json to ../data/all.json
# Processing ../data/64445.json
# Added ../data/64445.json to ../data/all.json
# Processing ../data/64446.json
# Added ../data/64446.json to ../data/all.json
# Added ../data/65007.json to ../data/all.json
# Processing ../data/65008.json
# Added ../data/65008.json to ../data/all.json
# Processing ../data/65009.json
# Added ../data/65009.json to ../data/all.json
# Processing ../data/65010.json
# Added ../data/65010.json to ../data/all.json
# Processing ../data/65011.json
# Added ../data/65011.json to ../data/all.json
# Processing ../data/65012.json
# Added ../data/65012.json to ../data/all.json
# Processing ../data/65013.json
# Added ../data/65013.json to ../data/all.json
# Processing ../data/65014.json
# Added ../data/65014.json to ../data/all.json
# Processing ../data/65015.json
# Added ../data/65015.json to ../data/all.json
# Processing ../data/65016.json
# Added ../data/65016.json to ../data/all.json
# Processing ../data/65017.json
# Added ../data/65017.json to ../data/all.json
# Processing ../data/65018.json
# Added ../data/65018.json to ../data/all.json
# Processing ../data/65019.json
# Added ../data/65019.json to ../data/all.json
# Processing ../data/65020.json
# Added ../data/65020.json to ../data/all.json
# Processing ../data/65021.json
# Added ../data/65021.json to ../data/all.json
# Processing ../data/65022.json
# Added ../data/65022.json to ../data/all.json
# Processing ../data/65023.json
# Added ../data/65023.json to ../data/all.json
# Processing ../data/65024.json
# Added ../data/65024.json to ../data/all.json
# Processing ../data/65025.json
# Added ../data/65025.json to ../data/all.json
# Processing ../data/65026.json
# Added ../data/65026.json to ../data/all.json
# Processing ../data/65027.json
# Added ../data/65027.json to ../data/all.json
# Processing ../data/65028.json
# Added ../data/65028.json to ../data/all.json
# Processing ../data/65029.json
# Added ../data/65029.json to ../data/all.json
# Processing ../data/65030.json
# Added ../data/65030.json to ../data/all.json
# Processing ../data/65031.json
# Added ../data/65031.json to ../data/all.json
# Processing ../data/65032.json
# Added ../data/65032.json to ../data/all.json
# Processing ../data/65033.json
# Added ../data/65033.json to ../data/all.json
# Processing ../data/65034.json
# Added ../data/65034.json to ../data/all.json
# Processing ../data/65035.json
# Added ../data/65035.json to ../data/all.json
# Processing ../data/65036.json
# Added ../data/65036.json to ../data/all.json
# Processing ../data/65037.json
# Added ../data/65037.json to ../data/all.json
# Processing ../data/65038.json
# Added ../data/65038.json to ../data/all.json
# Processing ../data/65039.json
# ...
# Processing ../data/66588.json
# Added ../data/66588.json to ../data/all.json
# Processing ../data/66589.json
# Added ../data/66589.json to ../data/all.json
# Processing ../data/66590.json
# Added ../data/66590.json to ../data/all.json
# Processing ../data/66591.json
# Added ../data/66591.json to ../data/all.json
# Processing ../data/66592.json
# Added ../data/66592.json to ../data/all.json
# Processing ../data/66593.json
# Added ../data/66593.json to ../data/all.json
# Processing ../data/66594.json
# Added ../data/66594.json to ../data/all.json
# Processing ../data/66595.json
# Added ../data/66595.json to ../data/all.json
# Processing ../data/66596.json
# Added ../data/66596.json to ../data/all.json
# Processing ../data/66597.json
# Added ../data/66597.json to ../data/all.json
# Processing ../data/66598.json
# Added ../data/66598.json to ../data/all.json
# Processing ../data/66599.json
# Added ../data/66599.json to ../data/all.json
# Processing ../data/66600.json
# Added ../data/66600.json to ../data/all.json
# Processing ../data/66601.json
# Added ../data/66601.json to ../data/all.json
# Processing ../data/66602.json
# Added ../data/66602.json to ../data/all.json
# Processing ../data/66603.json
# Added ../data/66603.json to ../data/all.json
# Processing ../data/66604.json
# Added ../data/66604.json to ../data/all.json
# Processing ../data/66605.json
# Added ../data/66605.json to ../data/all.json
# Processing ../data/66606.json
# Added ../data/66606.json to ../data/all.json
# Processing ../data/66607.json
# Added ../data/66607.json to ../data/all.json
# Processing ../data/66608.json
# Added ../data/66608.json to ../data/all.json
# Processing ../data/66609.json
# Added ../data/66609.json to ../data/all.json
# Processing ../data/66610.json
# Added ../data/66610.json to ../data/all.json
# Processing ../data/66611.json
# Added ../data/66611.json to ../data/all.json
# Processing ../data/66612.json
# Added ../data/66612.json to ../data/all.json
# Processing ../data/66613.json
# Added ../data/66613.json to ../data/all.json
# Processing ../data/66614.json
# Added ../data/66614.json to ../data/all.json
# Processing ../data/66615.json
# Added ../data/66615.json to ../data/all.json
# Processing ../data/66616.json
# Added ../data/66616.json to ../data/all.json
# Processing ../data/66617.json
# Added ../data/66617.json to ../data/all.json
# Processing ../data/66618.json
# Added ../data/66618.json to ../data/all.json
# Processing ../data/66619.json
# Added ../data/66619.json to ../data/all.json
# Processing ../data/66620.json
# Added ../data/66620.json to ../data/all.json
# Processing ../data/66621.json
# Added ../data/66621.json to ../data/all.json
# Processing ../data/66622.json
# Added ../data/66622.json to ../data/all.json
# Processing ../data/66623.json
# Added ../data/66623.json to ../data/all.json
# Processing ../data/66624.json
# Added ../data/66624.json to ../data/all.json
# Processing ../data/66625.json
# Added ../data/66625.json to ../data/all.json
# Processing ../data/66626.json
# Added ../data/66626.json to ../data/all.json
# Processing ../data/66627.json
# Added ../data/66627.json to ../data/all.json
# Processing ../data/66628.json
# Added ../data/66628.json to ../data/all.json
# Processing ../data/66629.json
# Added ../data/66629.json to ../data/all.json
# Processing ../data/66630.json
# Added ../data/66630.json to ../data/all.json
# Processing ../data/66631.json
# Added ../data/66631.json to ../data/all.json
# Processing ../data/66632.json
# Added ../data/66632.json to ../data/all.json
# Processing ../data/66633.json
# Added ../data/66633.json to ../data/all.json
# Processing ../data/66634.json
# Added ../data/66634.json to ../data/all.json
# Processing ../data/66635.json
# Added ../data/66635.json to ../data/all.json
# Processing ../data/66636.json
# Added ../data/66636.json to ../data/all.json
# Processing ../data/66637.json
# Added ../data/66637.json to ../data/all.json
# Processing ../data/66638.json
# Added ../data/66638.json to ../data/all.json
# Processing ../data/66639.json
# Added ../data/66639.json to ../data/all.json
# Processing ../data/66640.json
# Added ../data/66640.json to ../data/all.json
# Processing ../data/66641.json
# Added ../data/66641.json to ../data/all.json
# Processing ../data/66642.json
# Added ../data/66642.json to ../data/all.json
# Processing ../data/66643.json
# Added ../data/66643.json to ../data/all.json
# Processing ../data/66644.json
# Added ../data/66644.json to ../data/all.json
# Processing ../data/66645.json
# Added ../data/66645.json to ../data/all.json
# Processing ../data/66646.json
# Added ../data/66646.json to ../data/all.json
# Processing ../data/66647.json
# Added ../data/66647.json to ../data/all.json
# Processing ../data/66648.json
# Added ../data/66648.json to ../data/all.json
# Processing ../data/66649.json
# Added ../data/66649.json to ../data/all.json
# Processing ../data/66650.json
# Added ../data/66650.json to ../data/all.json
# Processing ../data/66651.json
# Added ../data/66651.json to ../data/all.json
# Processing ../data/66652.json
# Added ../data/66652.json to ../data/all.json
# Processing ../data/66653.json
# Added ../data/66653.json to ../data/all.json
# Processing ../data/66654.json
# Added ../data/66654.json to ../data/all.json
# Processing ../data/66655.json
# Added ../data/66655.json to ../data/all.json
# Processing ../data/66656.json
# Added ../data/66656.json to ../data/all.json
# Processing ../data/66657.json
# Added ../data/66657.json to ../data/all.json
# Processing ../data/66658.json
# Added ../data/66658.json to ../data/all.json
# Processing ../data/66659.json
# Added ../data/66659.json to ../data/all.json
# Processing ../data/66660.json
# Added ../data/66660.json to ../data/all.json
# Processing ../data/66661.json
# Added ../data/66661.json to ../data/all.json
# Processing ../data/66662.json
# Added ../data/66662.json to ../data/all.json
# Processing ../data/66663.json
# Added ../data/66663.json to ../data/all.json
# Processing ../data/66664.json
# Added ../data/66664.json to ../data/all.json
# Processing ../data/66665.json
# Added ../data/66665.json to ../data/all.json
# Processing ../data/66666.json
# Added ../data/66666.json to ../data/all.json
# Processing ../data/66667.json
# Added ../data/66667.json to ../data/all.json
# Processing ../data/66668.json
# Added ../data/66668.json to ../data/all.json
# Processing ../data/66669.json
# Added ../data/66669.json to ../data/all.json
# Processing ../data/66670.json
# Added ../data/66670.json to ../data/all.json
# Processing ../data/66671.json
# Added ../data/66671.json to ../data/all.json
# Processing ../data/66672.json
# Added ../data/66672.json to ../data/all.json
# Processing ../data/66673.json
# Added ../data/66673.json to ../data/all.json
# Processing ../data/66674.json
# Added ../data/66674.json to ../data/all.json
# Processing ../data/66675.json
# Added ../data/66675.json to ../data/all.json
# Processing ../data/66676.json
# Added ../data/66676.json to ../data/all.json
# Processing ../data/66677.json
# Added ../data/66677.json to ../data/all.json
# Processing ../data/66678.json
# Added ../data/66678.json to ../data/all.json
# Processing ../data/66679.json
# Added ../data/66679.json to ../data/all.json
# Processing ../data/66680.json
# Added ../data/66680.json to ../data/all.json
# Processing ../data/66681.json
# Added ../data/66681.json to ../data/all.json
# Processing ../data/66682.json
# Added ../data/66682.json to ../data/all.json
# Processing ../data/66683.json
# Added ../data/66683.json to ../data/all.json
# Processing ../data/66684.json
# Added ../data/66684.json to ../data/all.json
# Processing ../data/66685.json
# Added ../data/66685.json to ../data/all.json
# Processing ../data/66686.json
# Added ../data/66686.json to ../data/all.json
# Processing ../data/66687.json
# Added ../data/66687.json to ../data/all.json
# Processing ../data/66688.json
# Added ../data/66688.json to ../data/all.json
# Processing ../data/66689.json
# Added ../data/66689.json to ../data/all.json
# Processing ../data/66690.json
# Added ../data/66690.json to ../data/all.json
# Processing ../data/66691.json
# Added ../data/66691.json to ../data/all.json
# Processing ../data/66692.json
# Added ../data/66692.json to ../data/all.json
# Processing ../data/66693.json
# Added ../data/66693.json to ../data/all.json
# Processing ../data/66694.json
# Added ../data/66694.json to ../data/all.json
# Processing ../data/66695.json
# Added ../data/66695.json to ../data/all.json
# Processing ../data/66696.json
# Added ../data/66696.json to ../data/all.json
# Processing ../data/66697.json
# Added ../data/66697.json to ../data/all.json
# Processing ../data/66698.json
# Added ../data/66698.json to ../data/all.json
# Processing ../data/66699.json
# Added ../data/66699.json to ../data/all.json
# Processing ../data/66700.json
# Added ../data/66700.json to ../data/all.json
# Processing ../data/66701.json
# Added ../data/66701.json to ../data/all.json
# Processing ../data/66702.json
# Added ../data/66702.json to ../data/all.json
# Processing ../data/66703.json
# Added ../data/66703.json to ../data/all.json
# Processing ../data/66704.json
# Added ../data/66704.json to ../data/all.json
# Processing ../data/66705.json
# Added ../data/66705.json to ../data/all.json
# Processing ../data/66706.json
# Added ../data/66706.json to ../data/all.json
# Processing ../data/66707.json
# Added ../data/66707.json to ../data/all.json
# Processing ../data/66708.json
# Added ../data/66708.json to ../data/all.json
# Processing ../data/66709.json
# Added ../data/66709.json to ../data/all.json
# Processing ../data/66710.json
# Added ../data/66710.json to ../data/all.json
# Processing ../data/66711.json
# Added ../data/66711.json to ../data/all.json
# Processing ../data/66712.json
# Added ../data/66712.json to ../data/all.json
# Processing ../data/66713.json
# Added ../data/66713.json to ../data/all.json
# Processing ../data/66714.json
# Added ../data/66714.json to ../data/all.json
# Processing ../data/66715.json
# Added ../data/66715.json to ../data/all.json
# Processing ../data/66716.json
# Added ../data/66716.json to ../data/all.json
# Processing ../data/66717.json
# Added ../data/66717.json to ../data/all.json
# Processing ../data/66718.json
# Added ../data/66718.json to ../data/all.json
# Processing ../data/66719.json
# Added ../data/66719.json to ../data/all.json
# Processing ../data/66720.json
# Added ../data/66720.json to ../data/all.json
# Processing ../data/66721.json
# Added ../data/66721.json to ../data/all.json
# Processing ../data/66722.json
# Added ../data/66722.json to ../data/all.json
# Processing ../data/66723.json
# Added ../data/66723.json to ../data/all.json
# Processing ../data/66724.json
# Added ../data/66724.json to ../data/all.json
# Processing ../data/66725.json
# Added ../data/66725.json to ../data/all.json
# Processing ../data/66726.json
# Added ../data/66726.json to ../data/all.json
# Processing ../data/66727.json
# Added ../data/66727.json to ../data/all.json
# Processing ../data/66728.json
# Added ../data/66728.json to ../data/all.json
# Processing ../data/66729.json
# Added ../data/66729.json to ../data/all.json
# Processing ../data/66730.json
# Added ../data/66730.json to ../data/all.json
# Processing ../data/66731.json
# Added ../data/66731.json to ../data/all.json
# Processing ../data/66732.json
# Added ../data/66732.json to ../data/all.json
# Processing ../data/66733.json
# Added ../data/66733.json to ../data/all.json
# Processing ../data/66734.json
# Added ../data/66734.json to ../data/all.json
# Processing ../data/66735.json
# Added ../data/66735.json to ../data/all.json
# Processing ../data/66736.json
# Added ../data/66736.json to ../data/all.json
# Processing ../data/66737.json
# Added ../data/66737.json to ../data/all.json
# Processing ../data/66738.json
# Added ../data/66738.json to ../data/all.json
# Processing ../data/66739.json
# Added ../data/66739.json to ../data/all.json
# Processing ../data/66740.json
# Added ../data/66740.json to ../data/all.json
# Processing ../data/66741.json
# Added ../data/66741.json to ../data/all.json
# Processing ../data/66742.json
# Added ../data/66742.json to ../data/all.json
# Processing ../data/66743.json
# Added ../data/66743.json to ../data/all.json
# Processing ../data/66744.json
# Added ../data/66744.json to ../data/all.json
# Processing ../data/66745.json
# Added ../data/66745.json to ../data/all.json
# Processing ../data/66746.json
# Added ../data/66746.json to ../data/all.json
# Processing ../data/66747.json
# Added ../data/66747.json to ../data/all.json
# Processing ../data/66748.json
# Added ../data/66748.json to ../data/all.json
# Processing ../data/66749.json
# Added ../data/66749.json to ../data/all.json
# Processing ../data/66750.json
# Added ../data/66750.json to ../data/all.json
# Processing ../data/66751.json
# Added ../data/66751.json to ../data/all.json
# Processing ../data/66752.json
# Added ../data/66752.json to ../data/all.json
# Processing ../data/66753.json
# Added ../data/66753.json to ../data/all.json
# Processing ../data/66754.json
# Added ../data/66754.json to ../data/all.json
# Processing ../data/66755.json
# Added ../data/66755.json to ../data/all.json
# Processing ../data/66756.json
# Added ../data/66756.json to ../data/all.json
# Processing ../data/66757.json
# Added ../data/66757.json to ../data/all.json
# Processing ../data/66758.json
# Added ../data/66758.json to ../data/all.json
# Processing ../data/66759.json
# Added ../data/66759.json to ../data/all.json
# Processing ../data/66760.json
# Added ../data/66760.json to ../data/all.json
# Processing ../data/66761.json
# Added ../data/66761.json to ../data/all.json
# Processing ../data/66762.json
# Added ../data/66762.json to ../data/all.json
# Processing ../data/66763.json
# Added ../data/66763.json to ../data/all.json
# Processing ../data/66764.json
# Added ../data/66764.json to ../data/all.json
# Processing ../data/66765.json
# Added ../data/66765.json to ../data/all.json
# Processing ../data/66766.json
# Added ../data/66766.json to ../data/all.json
# Processing ../data/66767.json
# Added ../data/66767.json to ../data/all.json
# Processing ../data/66768.json
# Added ../data/66768.json to ../data/all.json
# Processing ../data/66769.json
# Added ../data/66769.json to ../data/all.json
# Processing ../data/66770.json
# Added ../data/66770.json to ../data/all.json
# Processing ../data/66771.json
# Added ../data/66771.json to ../data/all.json
# Processing ../data/66772.json
# Added ../data/66772.json to ../data/all.json
# Processing ../data/66773.json
# Added ../data/66773.json to ../data/all.json
# Processing ../data/66774.json
# Added ../data/66774.json to ../data/all.json
# Processing ../data/66775.json
# Added ../data/66775.json to ../data/all.json
# Processing ../data/66776.json
# Added ../data/66776.json to ../data/all.json
# Processing ../data/66777.json
# Added ../data/66777.json to ../data/all.json
# Processing ../data/66778.json
# Added ../data/66778.json to ../data/all.json
# Processing ../data/66779.json
# Added ../data/66779.json to ../data/all.json
# Processing ../data/66780.json
# Added ../data/66780.json to ../data/all.json
# Processing ../data/66781.json
# Added ../data/66781.json to ../data/all.json
# Processing ../data/66782.json
# Added ../data/66782.json to ../data/all.json
# Processing ../data/66783.json
# Added ../data/66783.json to ../data/all.json
# Processing ../data/66784.json
# Added ../data/66784.json to ../data/all.json
# Processing ../data/66785.json
# Added ../data/66785.json to ../data/all.json
# Processing ../data/66786.json
# Added ../data/66786.json to ../data/all.json
# Processing ../data/66787.json
# Added ../data/66787.json to ../data/all.json
# Processing ../data/66788.json
# Added ../data/66788.json to ../data/all.json
# Processing ../data/66789.json
# Added ../data/66789.json to ../data/all.json
# Processing ../data/66790.json
# Added ../data/66790.json to ../data/all.json
# Processing ../data/66791.json
# Added ../data/66791.json to ../data/all.json
# Processing ../data/66792.json
# Added ../data/66792.json to ../data/all.json
# Processing ../data/66793.json
# Added ../data/66793.json to ../data/all.json
# Processing ../data/66794.json
# Added ../data/66794.json to ../data/all.json
# Processing ../data/66795.json
# Added ../data/66795.json to ../data/all.json
# Processing ../data/66796.json
# Added ../data/66796.json to ../data/all.json
# Processing ../data/66797.json
# Added ../data/66797.json to ../data/all.json
# Processing ../data/66798.json
# Added ../data/66798.json to ../data/all.json
# Processing ../data/66799.json
# Added ../data/66799.json to ../data/all.json
# Wrapping file in json format
# All data stored in ../data/allfinal.json

# %% [markdown]
# ## Part 2: Converting the JSON file to CSV

# %%
## TEMP: correct shitty formatting errors from API
## store command line commands for now, see if error still persists next week
#sed -r -i.bak 's/\[\]\}\]\}\{\"ass/\[\]\}\,\{\"ass/g' allfinal.json
#sed -r -i.bak 's/\[\]\}\]\}\{\"clean/\[\]\}\,\{\"clean/g' allfinal.json

# %%
## adapted from https://gist.github.com/tjvc/12e393c48e0025509021

from collections import OrderedDict
import csv
import json
import sys

infile = "../data/allfinal.json"
outfile = open("../data/playerdata.csv", "w")

writer = csv.writer(outfile, delimiter=",")

data = json.load(open(infile), object_pairs_hook=OrderedDict)

# Recursively flatten JSON
def flatten(structure, key="", path="", flattened=None): 
    if flattened is None:
        flattened = OrderedDict()    
    if type(structure) not in(OrderedDict, list):
        flattened[((path + "_") if path else "") + key] = structure    
    elif isinstance(structure, list):
        for i, item in enumerate(structure):
            flatten(item, "", path + "_" + key, flattened)    
    else:
        for new_key, value in structure.items():
            flatten(value, new_key, path + "_" + key, flattened)    
    return flattened

# Write fields
fields = []
for result in data:
    flattened = flatten(result)
    for k, v in flattened.iteritems():
        if k not in fields:
            fields.append(k)
writer.writerow(fields)
print "Flattened JSON to the following fields:"
print fields

# Write values
for result in data:
    flattened = flatten(result)
    row = []
    for field in fields:
        if field in flattened.iterkeys():
            row.append(flattened[field])
        else:
            row.append("")
    writer.writerow(row)
print "Stored CSV as " + outfile.name
# Out:
# Flattened JSON to the following fields:
# [u'__assist', u'__clean_sheet', u'__goal', u'__matchday', u'__game_play_duration', u'__total_earnings', u'__matches_info__away_shortname', u'__matches_info__away_squad', u'__matches_info__away_score', u'__matches_info__time_on_pitch', u'__matches_info__player_status_status', u'__matches_info__player_status_id', u'__matches_info__player_status_match_id', u'__matches_info__period', u'__matches_info__finished', u'__matches_info__home_shortname', u'__matches_info__home_squad', u'__matches_info__home_score', u'__matches_info__player_status_in_for_player', u'__matches_info__player_status_sub_in_timestamp', u'__matches_info__player_status_sub_in_minutes', u'__matches_info__player_status_sub_out_minutes', u'__matches_info__player_status_sub_out_timestamp', u'__shot_on_target', u'__attempt_saved', u'__successful_pass']
# Stored CSV as ../data/playerdata.csv

# %%
print "Started at " + str(datetime.datetime.fromtimestamp(start_time))
print "Finished at " + str(datetime.datetime.fromtimestamp(time.time()))
