# %%
import json
import requests
import pprint
import os
import re
import time
import datetime

# %% [markdown]
# ## Part 1: Downloading data from API and joining in one big JSON file

# %%
start_time = time.time()
print "Starting at " + str(datetime.datetime.fromtimestamp(start_time))
BASE_URL = "http://www.playlivemanager.com/api/players/"
ROUND_URL_EXT = "/stats/round"
PLAYER_IDs = range(64400,66800)
# Out:
# Starting at 2016-02-26 18:01:32.201908

# %%
def query_by_id(playerID):
    print "Processing Player with ID " + playerID
    url = BASE_URL + playerID + ROUND_URL_EXT
    r = requests.get(url)
    print "requesting", r.url
    print r

    if r.status_code == requests.codes.ok:
        return r.json()
        print r.json()
    else:
        r.raise_for_status()

# %%
def download_data():
    for playerID in PLAYER_IDs:        
        results = query_by_id(str(playerID))
#        pprint.pprint(results)
        with open("../data/{0}.json".format(playerID), mode='w') as f:
            json.dump(results, f)
            print "Stored data for player " + str(playerID) + " in " + f.name

# %%
def transform_data():
    print "Deleting old files"
    try:
        os.remove("../data/all.json")
    except:
        pass
    print "Begin transforming data"
    for playerID in PLAYER_IDs:
        with open("../data/all.json", mode='a') as all:
            f = open("../data/{0}.json".format(playerID), 'r')
            print "Processing " + f.name
            file = f.read()
            file = file.strip()
            ## remove root
            file = re.sub('{\"status\": \"ok\", \"response\": \[', "", file)
            ## remove superfluous ']}' at the end and replace with ','
            file = re.sub("}}]}]}", "}}]},", file)
            #aggregate in one big json file
            #json.dump(file, all)
            all.write(file)
            #all.close()
            print "Added " + f.name + " to " + all.name

    # wrap content in '[]', replacing last ','
    with open("../data/allfinal.json", mode='w') as all:
        print "Wrapping file in json format"
        reader = open("../data/all.json", 'r').read()
        reader = '[' + reader
        reader = re.sub(r"\,$", r"]", reader)
        reader = reader.strip()
        all.write("%s\n" % reader)
    
    print "All data stored in " + all.name

# %%
download_data()
# Out:
# Processing Player with ID 65200
# requesting http://www.playlivemanager.com/api/players/65200/stats/round
# <Response [200]>
# Stored data for player 65200 in ../data/65200.json
# Processing Player with ID 65201
# requesting http://www.playlivemanager.com/api/players/65201/stats/round
# <Response [200]>
# Stored data for player 65201 in ../data/65201.json
# Processing Player with ID 65202
# requesting http://www.playlivemanager.com/api/players/65202/stats/round
# <Response [200]>
# Stored data for player 65202 in ../data/65202.json
# Processing Player with ID 65203
# requesting http://www.playlivemanager.com/api/players/65203/stats/round
# <Response [200]>
# Stored data for player 65203 in ../data/65203.json
# Processing Player with ID 65204
# requesting http://www.playlivemanager.com/api/players/65204/stats/round
# <Response [200]>
# Stored data for player 65204 in ../data/65204.json
# Processing Player with ID 65205
# requesting http://www.playlivemanager.com/api/players/65205/stats/round
# <Response [200]>
# Stored data for player 65205 in ../data/65205.json
# Processing Player with ID 65206
# requesting http://www.playlivemanager.com/api/players/65206/stats/round
# <Response [200]>
# Stored data for player 65206 in ../data/65206.json
# Processing Player with ID 65207
# requesting http://www.playlivemanager.com/api/players/65207/stats/round
# <Response [200]>
# Stored data for player 65207 in ../data/65207.json
# Processing Player with ID 65208
# requesting http://www.playlivemanager.com/api/players/65208/stats/round
# <Response [200]>
# Stored data for player 65208 in ../data/65208.json
# Processing Player with ID 65209
# requesting http://www.playlivemanager.com/api/players/65209/stats/round
# <Response [200]>
# Stored data for player 65209 in ../data/65209.json
# Processing Player with ID 65210
# requesting http://www.playlivemanager.com/api/players/65210/stats/round
# <Response [200]>
# Stored data for player 65210 in ../data/65210.json
# Processing Player with ID 65211
# requesting http://www.playlivemanager.com/api/players/65211/stats/round
# <Response [200]>
# Stored data for player 65211 in ../data/65211.json
# Processing Player with ID 65212
# requesting http://www.playlivemanager.com/api/players/65212/stats/round
# <Response [200]>
# Stored data for player 65212 in ../data/65212.json
# Processing Player with ID 65213
# requesting http://www.playlivemanager.com/api/players/65213/stats/round
# <Response [200]>
# Stored data for player 65213 in ../data/65213.json
# Processing Player with ID 65214
# requesting http://www.playlivemanager.com/api/players/65214/stats/round
# <Response [200]>
# Stored data for player 65214 in ../data/65214.json
# Processing Player with ID 65215
# requesting http://www.playlivemanager.com/api/players/65215/stats/round
# <Response [200]>
# Stored data for player 65215 in ../data/65215.json
# Processing Player with ID 65216
# requesting http://www.playlivemanager.com/api/players/65216/stats/round
# <Response [200]>
# Stored data for player 65216 in ../data/65216.json
# Processing Player with ID 65217
# requesting http://www.playlivemanager.com/api/players/65217/stats/round
# <Response [200]>
# Stored data for player 65217 in ../data/65217.json
# Processing Player with ID 65218
# requesting http://www.playlivemanager.com/api/players/65218/stats/round
# <Response [200]>
# Stored data for player 65218 in ../data/65218.json
# Processing Player with ID 65219
# requesting http://www.playlivemanager.com/api/players/65219/stats/round
# <Response [200]>
# Stored data for player 65219 in ../data/65219.json
# Processing Player with ID 65220
# requesting http://www.playlivemanager.com/api/players/65220/stats/round
# <Response [200]>
# Stored data for player 65220 in ../data/65220.json
# Processing Player with ID 65221
# requesting http://www.playlivemanager.com/api/players/65221/stats/round
# <Response [200]>
# Stored data for player 65221 in ../data/65221.json
# Processing Player with ID 65222
# requesting http://www.playlivemanager.com/api/players/65222/stats/round
# <Response [200]>
# Stored data for player 65222 in ../data/65222.json
# Processing Player with ID 65223
# requesting http://www.playlivemanager.com/api/players/65223/stats/round
# <Response [200]>
# Stored data for player 65223 in ../data/65223.json
# Processing Player with ID 65224
# requesting http://www.playlivemanager.com/api/players/65224/stats/round
# <Response [200]>
# Stored data for player 65224 in ../data/65224.json
# Processing Player with ID 65225
# requesting http://www.playlivemanager.com/api/players/65225/stats/round
# <Response [200]>
# Stored data for player 65225 in ../data/65225.json
# Processing Player with ID 65226
# requesting http://www.playlivemanager.com/api/players/65226/stats/round
# <Response [200]>
# Stored data for player 65226 in ../data/65226.json
# Processing Player with ID 65227
# requesting http://www.playlivemanager.com/api/players/65227/stats/round
# <Response [200]>
# Stored data for player 65227 in ../data/65227.json
# Processing Player with ID 65228
# requesting http://www.playlivemanager.com/api/players/65228/stats/round
# <Response [200]>
# Stored data for player 65228 in ../data/65228.json
# Processing Player with ID 65229
# requesting http://www.playlivemanager.com/api/players/65229/stats/round
# <Response [200]>
# Stored data for player 65229 in ../data/65229.json
# Processing Player with ID 65230
# requesting http://www.playlivemanager.com/api/players/65230/stats/round
# <Response [200]>
# Stored data for player 65230 in ../data/65230.json
# Processing Player with ID 65231
# requesting http://www.playlivemanager.com/api/players/65231/stats/round
# <Response [200]>
# Stored data for player 65231 in ../data/65231.json
# Processing Player with ID 65232
# requesting http://www.playlivemanager.com/api/players/65232/stats/round
# <Response [200]>
# Stored data for player 65232 in ../data/65232.json
# Processing Player with ID 65233
# requesting http://www.playlivemanager.com/api/players/65233/stats/round
# <Response [200]>
# Stored data for player 65233 in ../data/65233.json
# Processing Player with ID 65234
# requesting http://www.playlivemanager.com/api/players/65234/stats/round
# <Response [200]>
# Stored data for player 65234 in ../data/65234.json
# Processing Player with ID 65235
# requesting http://www.playlivemanager.com/api/players/65235/stats/round
# <Response [200]>
# Stored data for player 65235 in ../data/65235.json
# Processing Player with ID 65236
# requesting http://www.playlivemanager.com/api/players/65236/stats/round
# <Response [200]>
# Stored data for player 65236 in ../data/65236.json
# Processing Player with ID 65237
# requesting http://www.playlivemanager.com/api/players/65237/stats/round
# <Response [200]>
# Stored data for player 65237 in ../data/65237.json
# Processing Player with ID 65238
# requesting http://www.playlivemanager.com/api/players/65238/stats/round
# <Response [200]>
# Stored data for player 65238 in ../data/65238.json
# Processing Player with ID 65239
# requesting http://www.playlivemanager.com/api/players/65239/stats/round
# <Response [200]>
# Stored data for player 65239 in ../data/65239.json
# Processing Player with ID 65240
# requesting http://www.playlivemanager.com/api/players/65240/stats/round
# <Response [200]>
# Stored data for player 65240 in ../data/65240.json
# Processing Player with ID 65241
# requesting http://www.playlivemanager.com/api/players/65241/stats/round
# <Response [200]>
# Stored data for player 65241 in ../data/65241.json
# Processing Player with ID 65242
# requesting http://www.playlivemanager.com/api/players/65242/stats/round
# <Response [200]>
# Stored data for player 65242 in ../data/65242.json
# Processing Player with ID 65243
# requesting http://www.playlivemanager.com/api/players/65243/stats/round
# <Response [200]>
# Stored data for player 65243 in ../data/65243.json
# Processing Player with ID 65244
# requesting http://www.playlivemanager.com/api/players/65244/stats/round
# <Response [200]>
# Stored data for player 65244 in ../data/65244.json
# Processing Player with ID 65245
# requesting http://www.playlivemanager.com/api/players/65245/stats/round
# <Response [200]>
# Stored data for player 65245 in ../data/65245.json
# Processing Player with ID 65246
# requesting http://www.playlivemanager.com/api/players/65246/stats/round
# <Response [200]>
# Stored data for player 65246 in ../data/65246.json
# Processing Player with ID 65247
# requesting http://www.playlivemanager.com/api/players/65247/stats/round
# <Response [200]>
# Stored data for player 65247 in ../data/65247.json
# Processing Player with ID 65248
# requesting http://www.playlivemanager.com/api/players/65248/stats/round
# <Response [200]>
# Stored data for player 65248 in ../data/65248.json
# Processing Player with ID 65249
# requesting http://www.playlivemanager.com/api/players/65249/stats/round
# <Response [200]>
# Stored data for player 65249 in ../data/65249.json
# Processing Player with ID 65250
# requesting http://www.playlivemanager.com/api/players/65250/stats/round
# <Response [200]>
# Stored data for player 65250 in ../data/65250.json
# Processing Player with ID 65251
# requesting http://www.playlivemanager.com/api/players/65251/stats/round
# <Response [200]>
# Stored data for player 65251 in ../data/65251.json
# Processing Player with ID 65252
# requesting http://www.playlivemanager.com/api/players/65252/stats/round
# <Response [200]>
# Stored data for player 65252 in ../data/65252.json
# Processing Player with ID 65253
# requesting http://www.playlivemanager.com/api/players/65253/stats/round
# <Response [200]>
# Stored data for player 65253 in ../data/65253.json
# Processing Player with ID 65254
# requesting http://www.playlivemanager.com/api/players/65254/stats/round
# <Response [200]>
# Stored data for player 65254 in ../data/65254.json
# Processing Player with ID 65255
# requesting http://www.playlivemanager.com/api/players/65255/stats/round
# <Response [200]>
# Stored data for player 65255 in ../data/65255.json
# Processing Player with ID 65256
# requesting http://www.playlivemanager.com/api/players/65256/stats/round
# <Response [200]>
# Stored data for player 65256 in ../data/65256.json
# Processing Player with ID 65257
# requesting http://www.playlivemanager.com/api/players/65257/stats/round
# <Response [200]>
# Stored data for player 65257 in ../data/65257.json
# Processing Player with ID 65258
# requesting http://www.playlivemanager.com/api/players/65258/stats/round
# <Response [200]>
# Stored data for player 65258 in ../data/65258.json
# Processing Player with ID 65259
# requesting http://www.playlivemanager.com/api/players/65259/stats/round
# <Response [200]>
# Stored data for player 65259 in ../data/65259.json
# Processing Player with ID 65260
# requesting http://www.playlivemanager.com/api/players/65260/stats/round
# <Response [200]>
# Stored data for player 65260 in ../data/65260.json
# Processing Player with ID 65261
# requesting http://www.playlivemanager.com/api/players/65261/stats/round
# <Response [200]>
# Stored data for player 65261 in ../data/65261.json
# Processing Player with ID 65262
# requesting http://www.playlivemanager.com/api/players/65262/stats/round
# <Response [200]>
# Stored data for player 65262 in ../data/65262.json
# Processing Player with ID 65263
# requesting http://www.playlivemanager.com/api/players/65263/stats/round
# <Response [200]>
# Stored data for player 65263 in ../data/65263.json
# Processing Player with ID 65264
# requesting http://www.playlivemanager.com/api/players/65264/stats/round
# <Response [200]>
# Stored data for player 65264 in ../data/65264.json
# Processing Player with ID 65265
# requesting http://www.playlivemanager.com/api/players/65265/stats/round
# <Response [200]>
# Stored data for player 65265 in ../data/65265.json
# Processing Player with ID 65266
# requesting http://www.playlivemanager.com/api/players/65266/stats/round
# <Response [200]>
# Stored data for player 65266 in ../data/65266.json
# Processing Player with ID 65267
# requesting http://www.playlivemanager.com/api/players/65267/stats/round
# <Response [200]>
# Stored data for player 65267 in ../data/65267.json
# Processing Player with ID 65268
# requesting http://www.playlivemanager.com/api/players/65268/stats/round
# <Response [200]>
# Stored data for player 65268 in ../data/65268.json
# Processing Player with ID 65269
# requesting http://www.playlivemanager.com/api/players/65269/stats/round
# <Response [200]>
# Stored data for player 65269 in ../data/65269.json
# Processing Player with ID 65270
# requesting http://www.playlivemanager.com/api/players/65270/stats/round
# <Response [200]>
# Stored data for player 65270 in ../data/65270.json
# Processing Player with ID 65271
# requesting http://www.playlivemanager.com/api/players/65271/stats/round
# <Response [200]>
# Stored data for player 65271 in ../data/65271.json
# Processing Player with ID 65272
# requesting http://www.playlivemanager.com/api/players/65272/stats/round
# <Response [200]>
# Stored data for player 65272 in ../data/65272.json
# Processing Player with ID 65273
# requesting http://www.playlivemanager.com/api/players/65273/stats/round
# <Response [200]>
# Stored data for player 65273 in ../data/65273.json
# Processing Player with ID 65274
# requesting http://www.playlivemanager.com/api/players/65274/stats/round
# <Response [200]>
# Stored data for player 65274 in ../data/65274.json
# Processing Player with ID 65275
# requesting http://www.playlivemanager.com/api/players/65275/stats/round
# <Response [200]>
# Stored data for player 65275 in ../data/65275.json
# Processing Player with ID 65276
# requesting http://www.playlivemanager.com/api/players/65276/stats/round
# <Response [200]>
# Stored data for player 65276 in ../data/65276.json
# Processing Player with ID 65277
# requesting http://www.playlivemanager.com/api/players/65277/stats/round
# <Response [200]>
# Stored data for player 65277 in ../data/65277.json
# Processing Player with ID 65278
# requesting http://www.playlivemanager.com/api/players/65278/stats/round
# <Response [200]>
# Stored data for player 65278 in ../data/65278.json
# Processing Player with ID 65279
# requesting http://www.playlivemanager.com/api/players/65279/stats/round
# <Response [200]>
# Stored data for player 65279 in ../data/65279.json
# Processing Player with ID 65280
# requesting http://www.playlivemanager.com/api/players/65280/stats/round
# <Response [200]>
# Stored data for player 65280 in ../data/65280.json
# Processing Player with ID 65281
# requesting http://www.playlivemanager.com/api/players/65281/stats/round
# <Response [200]>
# Stored data for player 65281 in ../data/65281.json
# Processing Player with ID 65282
# requesting http://www.playlivemanager.com/api/players/65282/stats/round
# <Response [200]>
# Stored data for player 65282 in ../data/65282.json
# Processing Player with ID 65283
# requesting http://www.playlivemanager.com/api/players/65283/stats/round
# <Response [200]>
# Stored data for player 65283 in ../data/65283.json
# Processing Player with ID 65284
# requesting http://www.playlivemanager.com/api/players/65284/stats/round
# <Response [200]>
# Stored data for player 65284 in ../data/65284.json
# Processing Player with ID 65285
# requesting http://www.playlivemanager.com/api/players/65285/stats/round
# <Response [200]>
# Stored data for player 65285 in ../data/65285.json
# Processing Player with ID 65286
# requesting http://www.playlivemanager.com/api/players/65286/stats/round
# <Response [200]>
# Stored data for player 65286 in ../data/65286.json
# Processing Player with ID 65287
# requesting http://www.playlivemanager.com/api/players/65287/stats/round
# <Response [200]>
# Stored data for player 65287 in ../data/65287.json
# Processing Player with ID 65288
# requesting http://www.playlivemanager.com/api/players/65288/stats/round
# <Response [200]>
# Stored data for player 65288 in ../data/65288.json
# Processing Player with ID 65289
# requesting http://www.playlivemanager.com/api/players/65289/stats/round
# <Response [200]>
# Stored data for player 65289 in ../data/65289.json
# Processing Player with ID 65290
# requesting http://www.playlivemanager.com/api/players/65290/stats/round
# <Response [200]>
# Stored data for player 65290 in ../data/65290.json
# Processing Player with ID 65291
# requesting http://www.playlivemanager.com/api/players/65291/stats/round
# <Response [200]>
# Stored data for player 65291 in ../data/65291.json
# Processing Player with ID 65292
# requesting http://www.playlivemanager.com/api/players/65292/stats/round
# <Response [200]>
# Stored data for player 65292 in ../data/65292.json
# Processing Player with ID 65293
# requesting http://www.playlivemanager.com/api/players/65293/stats/round
# <Response [200]>
# Stored data for player 65293 in ../data/65293.json
# Processing Player with ID 65294
# requesting http://www.playlivemanager.com/api/players/65294/stats/round
# <Response [200]>
# Stored data for player 65294 in ../data/65294.json
# Processing Player with ID 65295
# requesting http://www.playlivemanager.com/api/players/65295/stats/round
# <Response [200]>
# Stored data for player 65295 in ../data/65295.json
# Processing Player with ID 65296
# requesting http://www.playlivemanager.com/api/players/65296/stats/round
# <Response [200]>
# Stored data for player 65296 in ../data/65296.json
# Processing Player with ID 65297
# requesting http://www.playlivemanager.com/api/players/65297/stats/round
# <Response [200]>
# Stored data for player 65297 in ../data/65297.json
# Processing Player with ID 65298
# requesting http://www.playlivemanager.com/api/players/65298/stats/round
# <Response [200]>
# Stored data for player 65298 in ../data/65298.json
# Processing Player with ID 65299
# requesting http://www.playlivemanager.com/api/players/65299/stats/round
# <Response [200]>
# Stored data for player 65299 in ../data/65299.json
# Processing Player with ID 65300
# requesting http://www.playlivemanager.com/api/players/65300/stats/round
# <Response [200]>
# Stored data for player 65300 in ../data/65300.json
# Processing Player with ID 65301
# requesting http://www.playlivemanager.com/api/players/65301/stats/round
# <Response [200]>
# Stored data for player 65301 in ../data/65301.json
# Processing Player with ID 65302
# requesting http://www.playlivemanager.com/api/players/65302/stats/round
# <Response [200]>
# Stored data for player 65302 in ../data/65302.json
# Processing Player with ID 65303
# requesting http://www.playlivemanager.com/api/players/65303/stats/round
# <Response [200]>
# Stored data for player 65303 in ../data/65303.json
# Processing Player with ID 65304
# requesting http://www.playlivemanager.com/api/players/65304/stats/round
# <Response [200]>
# Stored data for player 65304 in ../data/65304.json
# Processing Player with ID 65305
# requesting http://www.playlivemanager.com/api/players/65305/stats/round
# <Response [200]>
# Stored data for player 65305 in ../data/65305.json
# Processing Player with ID 65306
# requesting http://www.playlivemanager.com/api/players/65306/stats/round
# <Response [200]>
# Stored data for player 65306 in ../data/65306.json
# Processing Player with ID 65307
# requesting http://www.playlivemanager.com/api/players/65307/stats/round
# <Response [200]>
# Stored data for player 65307 in ../data/65307.json
# Processing Player with ID 65308
# requesting http://www.playlivemanager.com/api/players/65308/stats/round
# <Response [200]>
# Stored data for player 65308 in ../data/65308.json
# Processing Player with ID 65309
# requesting http://www.playlivemanager.com/api/players/65309/stats/round
# <Response [200]>
# Stored data for player 65309 in ../data/65309.json
# Processing Player with ID 65310
# requesting http://www.playlivemanager.com/api/players/65310/stats/round
# <Response [200]>
# Stored data for player 65310 in ../data/65310.json
# Processing Player with ID 65311
# requesting http://www.playlivemanager.com/api/players/65311/stats/round
# <Response [200]>
# Stored data for player 65311 in ../data/65311.json
# Processing Player with ID 65312
# requesting http://www.playlivemanager.com/api/players/65312/stats/round
# <Response [200]>
# Stored data for player 65312 in ../data/65312.json
# Processing Player with ID 65313
# requesting http://www.playlivemanager.com/api/players/65313/stats/round
# <Response [200]>
# Stored data for player 65313 in ../data/65313.json
# Processing Player with ID 65314
# requesting http://www.playlivemanager.com/api/players/65314/stats/round
# <Response [200]>
# Stored data for player 65314 in ../data/65314.json
# Processing Player with ID 65315
# requesting http://www.playlivemanager.com/api/players/65315/stats/round
# <Response [200]>
# Stored data for player 65315 in ../data/65315.json
# Processing Player with ID 65316
# requesting http://www.playlivemanager.com/api/players/65316/stats/round
# <Response [200]>
# Stored data for player 65316 in ../data/65316.json
# Processing Player with ID 65317
# requesting http://www.playlivemanager.com/api/players/65317/stats/round
# <Response [200]>
# Stored data for player 65317 in ../data/65317.json
# Processing Player with ID 65318
# requesting http://www.playlivemanager.com/api/players/65318/stats/round
# <Response [200]>
# Stored data for player 65318 in ../data/65318.json
# Processing Player with ID 65319
# requesting http://www.playlivemanager.com/api/players/65319/stats/round
# <Response [200]>
# Stored data for player 65319 in ../data/65319.json
# Processing Player with ID 65320
# requesting http://www.playlivemanager.com/api/players/65320/stats/round
# <Response [200]>
# Stored data for player 65320 in ../data/65320.json
# Processing Player with ID 65321
# requesting http://www.playlivemanager.com/api/players/65321/stats/round
# <Response [200]>
# Stored data for player 65321 in ../data/65321.json
# Processing Player with ID 65322
# requesting http://www.playlivemanager.com/api/players/65322/stats/round
# <Response [200]>
# Stored data for player 65322 in ../data/65322.json
# Processing Player with ID 65323
# requesting http://www.playlivemanager.com/api/players/65323/stats/round
# <Response [200]>
# Stored data for player 65323 in ../data/65323.json
# Processing Player with ID 65324
# requesting http://www.playlivemanager.com/api/players/65324/stats/round
# <Response [200]>
# Stored data for player 65324 in ../data/65324.json
# Processing Player with ID 65325
# requesting http://www.playlivemanager.com/api/players/65325/stats/round
# <Response [200]>
# Stored data for player 65325 in ../data/65325.json
# Processing Player with ID 65326
# requesting http://www.playlivemanager.com/api/players/65326/stats/round
# <Response [200]>
# Stored data for player 65326 in ../data/65326.json
# Processing Player with ID 65327
# requesting http://www.playlivemanager.com/api/players/65327/stats/round
# <Response [200]>
# Stored data for player 65327 in ../data/65327.json
# Processing Player with ID 65328
# requesting http://www.playlivemanager.com/api/players/65328/stats/round
# <Response [200]>
# Stored data for player 65328 in ../data/65328.json
# Processing Player with ID 65329
# requesting http://www.playlivemanager.com/api/players/65329/stats/round
# <Response [200]>
# Stored data for player 65329 in ../data/65329.json
# Processing Player with ID 65330
# requesting http://www.playlivemanager.com/api/players/65330/stats/round
# <Response [200]>
# Stored data for player 65330 in ../data/65330.json
# Processing Player with ID 65331
# requesting http://www.playlivemanager.com/api/players/65331/stats/round
# <Response [200]>
# Stored data for player 65331 in ../data/65331.json
# Processing Player with ID 65332
# requesting http://www.playlivemanager.com/api/players/65332/stats/round
# <Response [200]>
# Stored data for player 65332 in ../data/65332.json
# Processing Player with ID 65333
# requesting http://www.playlivemanager.com/api/players/65333/stats/round
# <Response [200]>
# Stored data for player 65333 in ../data/65333.json
# Processing Player with ID 65334
# requesting http://www.playlivemanager.com/api/players/65334/stats/round
# <Response [200]>
# Stored data for player 65334 in ../data/65334.json
# Processing Player with ID 65335
# requesting http://www.playlivemanager.com/api/players/65335/stats/round
# <Response [200]>
# Stored data for player 65335 in ../data/65335.json
# Processing Player with ID 65336
# requesting http://www.playlivemanager.com/api/players/65336/stats/round
# <Response [200]>
# Stored data for player 65336 in ../data/65336.json
# Processing Player with ID 65337
# requesting http://www.playlivemanager.com/api/players/65337/stats/round
# <Response [200]>
# Stored data for player 65337 in ../data/65337.json
# Processing Player with ID 65338
# requesting http://www.playlivemanager.com/api/players/65338/stats/round
# <Response [200]>
# Stored data for player 65338 in ../data/65338.json
# Processing Player with ID 65339
# requesting http://www.playlivemanager.com/api/players/65339/stats/round
# <Response [200]>
# Stored data for player 65339 in ../data/65339.json
# Processing Player with ID 65340
# requesting http://www.playlivemanager.com/api/players/65340/stats/round
# <Response [200]>
# Stored data for player 65340 in ../data/65340.json
# Processing Player with ID 65341
# requesting http://www.playlivemanager.com/api/players/65341/stats/round
# <Response [200]>
# Stored data for player 65341 in ../data/65341.json
# Processing Player with ID 65342
# requesting http://www.playlivemanager.com/api/players/65342/stats/round
# <Response [200]>
# Stored data for player 65342 in ../data/65342.json
# Processing Player with ID 65343
# requesting http://www.playlivemanager.com/api/players/65343/stats/round
# <Response [200]>
# Stored data for player 65343 in ../data/65343.json
# Processing Player with ID 65344
# requesting http://www.playlivemanager.com/api/players/65344/stats/round
# <Response [200]>
# Stored data for player 65344 in ../data/65344.json
# Processing Player with ID 65345
# requesting http://www.playlivemanager.com/api/players/65345/stats/round
# <Response [200]>
# Stored data for player 65345 in ../data/65345.json
# Processing Player with ID 65346
# requesting http://www.playlivemanager.com/api/players/65346/stats/round
# <Response [200]>
# Stored data for player 65346 in ../data/65346.json
# Processing Player with ID 65347
# requesting http://www.playlivemanager.com/api/players/65347/stats/round
# <Response [200]>
# Stored data for player 65347 in ../data/65347.json
# Processing Player with ID 65348
# requesting http://www.playlivemanager.com/api/players/65348/stats/round
# <Response [200]>
# Stored data for player 65348 in ../data/65348.json
# Processing Player with ID 65349
# requesting http://www.playlivemanager.com/api/players/65349/stats/round
# <Response [200]>
# Stored data for player 65349 in ../data/65349.json
# Processing Player with ID 65350
# requesting http://www.playlivemanager.com/api/players/65350/stats/round
# <Response [200]>
# Stored data for player 65350 in ../data/65350.json
# Processing Player with ID 65351
# requesting http://www.playlivemanager.com/api/players/65351/stats/round
# <Response [200]>
# Stored data for player 65351 in ../data/65351.json
# Processing Player with ID 65352
# requesting http://www.playlivemanager.com/api/players/65352/stats/round
# <Response [200]>
# Stored data for player 65352 in ../data/65352.json
# Processing Player with ID 65353
# requesting http://www.playlivemanager.com/api/players/65353/stats/round
# <Response [200]>
# Stored data for player 65353 in ../data/65353.json
# Processing Player with ID 65354
# requesting http://www.playlivemanager.com/api/players/65354/stats/round
# <Response [200]>
# Stored data for player 65354 in ../data/65354.json
# Processing Player with ID 65355
# requesting http://www.playlivemanager.com/api/players/65355/stats/round
# <Response [200]>
# Stored data for player 65355 in ../data/65355.json
# Processing Player with ID 65356
# requesting http://www.playlivemanager.com/api/players/65356/stats/round
# <Response [200]>
# Stored data for player 65356 in ../data/65356.json
# Processing Player with ID 65357
# requesting http://www.playlivemanager.com/api/players/65357/stats/round
# <Response [200]>
# Stored data for player 65357 in ../data/65357.json
# Processing Player with ID 65358
# requesting http://www.playlivemanager.com/api/players/65358/stats/round
# <Response [200]>
# Stored data for player 65358 in ../data/65358.json
# Processing Player with ID 65359
# requesting http://www.playlivemanager.com/api/players/65359/stats/round
# <Response [200]>
# Stored data for player 65359 in ../data/65359.json
# Processing Player with ID 65360
# requesting http://www.playlivemanager.com/api/players/65360/stats/round
# <Response [200]>
# Stored data for player 65360 in ../data/65360.json
# Processing Player with ID 65361
# requesting http://www.playlivemanager.com/api/players/65361/stats/round
# <Response [200]>
# Stored data for player 65361 in ../data/65361.json
# Processing Player with ID 65362
# requesting http://www.playlivemanager.com/api/players/65362/stats/round
# <Response [200]>
# Stored data for player 65362 in ../data/65362.json
# Processing Player with ID 65363
# requesting http://www.playlivemanager.com/api/players/65363/stats/round
# <Response [200]>
# Stored data for player 65363 in ../data/65363.json
# Processing Player with ID 65364
# requesting http://www.playlivemanager.com/api/players/65364/stats/round
# <Response [200]>
# Stored data for player 65364 in ../data/65364.json
# Processing Player with ID 65365
# requesting http://www.playlivemanager.com/api/players/65365/stats/round
# <Response [200]>
# Stored data for player 65365 in ../data/65365.json
# Processing Player with ID 65366
# requesting http://www.playlivemanager.com/api/players/65366/stats/round
# <Response [200]>
# Stored data for player 65366 in ../data/65366.json
# Processing Player with ID 65367
# requesting http://www.playlivemanager.com/api/players/65367/stats/round
# <Response [200]>
# Stored data for player 65367 in ../data/65367.json
# Processing Player with ID 65368
# requesting http://www.playlivemanager.com/api/players/65368/stats/round
# <Response [200]>
# Stored data for player 65368 in ../data/65368.json
# Processing Player with ID 65369
# requesting http://www.playlivemanager.com/api/players/65369/stats/round
# <Response [200]>
# Stored data for player 65369 in ../data/65369.json
# Processing Player with ID 65370
# requesting http://www.playlivemanager.com/api/players/65370/stats/round
# <Response [200]>
# Stored data for player 65370 in ../data/65370.json
# Processing Player with ID 65371
# requesting http://www.playlivemanager.com/api/players/65371/stats/round
# <Response [200]>
# Stored data for player 65371 in ../data/65371.json
# Processing Player with ID 65372
# requesting http://www.playlivemanager.com/api/players/65372/stats/round
# <Response [200]>
# Stored data for player 65372 in ../data/65372.json
# Processing Player with ID 65373
# requesting http://www.playlivemanager.com/api/players/65373/stats/round
# <Response [200]>
# Stored data for player 65373 in ../data/65373.json
# Processing Player with ID 65374
# requesting http://www.playlivemanager.com/api/players/65374/stats/round
# <Response [200]>
# Stored data for player 65374 in ../data/65374.json
# Processing Player with ID 65375
# requesting http://www.playlivemanager.com/api/players/65375/stats/round
# <Response [200]>
# Stored data for player 65375 in ../data/65375.json
# Processing Player with ID 65376
# requesting http://www.playlivemanager.com/api/players/65376/stats/round
# <Response [200]>
# Stored data for player 65376 in ../data/65376.json
# Processing Player with ID 65377
# requesting http://www.playlivemanager.com/api/players/65377/stats/round
# <Response [200]>
# Stored data for player 65377 in ../data/65377.json
# Processing Player with ID 65378
# requesting http://www.playlivemanager.com/api/players/65378/stats/round
# <Response [200]>
# Stored data for player 65378 in ../data/65378.json
# Processing Player with ID 65379
# requesting http://www.playlivemanager.com/api/players/65379/stats/round
# <Response [200]>
# Stored data for player 65379 in ../data/65379.json
# Processing Player with ID 65380
# requesting http://www.playlivemanager.com/api/players/65380/stats/round
# <Response [200]>
# Stored data for player 65380 in ../data/65380.json
# Processing Player with ID 65381
# requesting http://www.playlivemanager.com/api/players/65381/stats/round
# <Response [200]>
# Stored data for player 65381 in ../data/65381.json
# Processing Player with ID 65382
# requesting http://www.playlivemanager.com/api/players/65382/stats/round
# <Response [200]>
# Stored data for player 65382 in ../data/65382.json
# Processing Player with ID 65383
# requesting http://www.playlivemanager.com/api/players/65383/stats/round
# <Response [200]>
# Stored data for player 65383 in ../data/65383.json
# Processing Player with ID 65384
# requesting http://www.playlivemanager.com/api/players/65384/stats/round
# <Response [200]>
# Stored data for player 65384 in ../data/65384.json
# Processing Player with ID 65385
# requesting http://www.playlivemanager.com/api/players/65385/stats/round
# <Response [200]>
# Stored data for player 65385 in ../data/65385.json
# Processing Player with ID 65386
# requesting http://www.playlivemanager.com/api/players/65386/stats/round
# <Response [200]>
# Stored data for player 65386 in ../data/65386.json
# Processing Player with ID 65387
# requesting http://www.playlivemanager.com/api/players/65387/stats/round
# <Response [200]>
# Stored data for player 65387 in ../data/65387.json
# Processing Player with ID 65388
# requesting http://www.playlivemanager.com/api/players/65388/stats/round
# <Response [200]>
# Stored data for player 65388 in ../data/65388.json
# Processing Player with ID 65389
# requesting http://www.playlivemanager.com/api/players/65389/stats/round
# <Response [200]>
# Stored data for player 65389 in ../data/65389.json
# Processing Player with ID 65390
# requesting http://www.playlivemanager.com/api/players/65390/stats/round
# <Response [200]>
# Stored data for player 65390 in ../data/65390.json
# Processing Player with ID 65391
# requesting http://www.playlivemanager.com/api/players/65391/stats/round
# <Response [200]>
# Stored data for player 65391 in ../data/65391.json
# Processing Player with ID 65392
# requesting http://www.playlivemanager.com/api/players/65392/stats/round
# <Response [200]>
# Stored data for player 65392 in ../data/65392.json
# Processing Player with ID 65393
# requesting http://www.playlivemanager.com/api/players/65393/stats/round
# <Response [200]>
# Stored data for player 65393 in ../data/65393.json
# Processing Player with ID 65394
# requesting http://www.playlivemanager.com/api/players/65394/stats/round
# <Response [200]>
# Stored data for player 65394 in ../data/65394.json
# Processing Player with ID 65395
# requesting http://www.playlivemanager.com/api/players/65395/stats/round
# <Response [200]>
# Stored data for player 65395 in ../data/65395.json
# Processing Player with ID 65396
# requesting http://www.playlivemanager.com/api/players/65396/stats/round
# <Response [200]>
# Stored data for player 65396 in ../data/65396.json
# Processing Player with ID 65397
# requesting http://www.playlivemanager.com/api/players/65397/stats/round
# <Response [200]>
# Stored data for player 65397 in ../data/65397.json
# Processing Player with ID 65398
# requesting http://www.playlivemanager.com/api/players/65398/stats/round
# <Response [200]>
# Stored data for player 65398 in ../data/65398.json
# Processing Player with ID 65399
# requesting http://www.playlivemanager.com/api/players/65399/stats/round
# <Response [200]>
# Stored data for player 65399 in ../data/65399.json
# Processing Player with ID 65400
# requesting http://www.playlivemanager.com/api/players/65400/stats/round
# <Response [200]>
# Stored data for player 65400 in ../data/65400.json
# Processing Player with ID 65401
# requesting http://www.playlivemanager.com/api/players/65401/stats/round
# <Response [200]>
# Stored data for player 65401 in ../data/65401.json
# Processing Player with ID 65402
# requesting http://www.playlivemanager.com/api/players/65402/stats/round
# <Response [200]>
# Stored data for player 65402 in ../data/65402.json
# Processing Player with ID 65403
# requesting http://www.playlivemanager.com/api/players/65403/stats/round
# <Response [200]>
# Stored data for player 65403 in ../data/65403.json
# Processing Player with ID 65404
# requesting http://www.playlivemanager.com/api/players/65404/stats/round
# <Response [200]>
# Stored data for player 65404 in ../data/65404.json
# Processing Player with ID 65405
# requesting http://www.playlivemanager.com/api/players/65405/stats/round
# <Response [200]>
# Stored data for player 65405 in ../data/65405.json
# Processing Player with ID 65406
# requesting http://www.playlivemanager.com/api/players/65406/stats/round
# <Response [200]>
# Stored data for player 65406 in ../data/65406.json
# Processing Player with ID 65407
# requesting http://www.playlivemanager.com/api/players/65407/stats/round
# <Response [200]>
# Stored data for player 65407 in ../data/65407.json
# Processing Player with ID 65408
# requesting http://www.playlivemanager.com/api/players/65408/stats/round
# <Response [200]>
# Stored data for player 65408 in ../data/65408.json
# Processing Player with ID 65409
# requesting http://www.playlivemanager.com/api/players/65409/stats/round
# <Response [200]>
# Stored data for player 65409 in ../data/65409.json
# Processing Player with ID 65410
# requesting http://www.playlivemanager.com/api/players/65410/stats/round
# <Response [200]>
# Stored data for player 65410 in ../data/65410.json
# Processing Player with ID 65411
# requesting http://www.playlivemanager.com/api/players/65411/stats/round
# <Response [200]>
# Stored data for player 65411 in ../data/65411.json
# Processing Player with ID 65412
# requesting http://www.playlivemanager.com/api/players/65412/stats/round
# <Response [200]>
# Stored data for player 65412 in ../data/65412.json
# Processing Player with ID 65413
# requesting http://www.playlivemanager.com/api/players/65413/stats/round
# <Response [200]>
# Stored data for player 65413 in ../data/65413.json
# Processing Player with ID 65414
# requesting http://www.playlivemanager.com/api/players/65414/stats/round
# <Response [200]>
# Stored data for player 65414 in ../data/65414.json
# Processing Player with ID 65415
# requesting http://www.playlivemanager.com/api/players/65415/stats/round
# <Response [200]>
# Stored data for player 65415 in ../data/65415.json
# Processing Player with ID 65416
# requesting http://www.playlivemanager.com/api/players/65416/stats/round
# <Response [200]>
# Stored data for player 65416 in ../data/65416.json
# Processing Player with ID 65417
# requesting http://www.playlivemanager.com/api/players/65417/stats/round
# <Response [200]>
# Stored data for player 65417 in ../data/65417.json
# Processing Player with ID 65418
# requesting http://www.playlivemanager.com/api/players/65418/stats/round
# <Response [200]>
# Stored data for player 65418 in ../data/65418.json
# Processing Player with ID 65419
# requesting http://www.playlivemanager.com/api/players/65419/stats/round
# <Response [200]>
# Stored data for player 65419 in ../data/65419.json
# Processing Player with ID 65420
# requesting http://www.playlivemanager.com/api/players/65420/stats/round
# <Response [200]>
# Stored data for player 65420 in ../data/65420.json
# Processing Player with ID 65421
# requesting http://www.playlivemanager.com/api/players/65421/stats/round
# <Response [200]>
# Stored data for player 65421 in ../data/65421.json
# Processing Player with ID 65422
# requesting http://www.playlivemanager.com/api/players/65422/stats/round
# <Response [200]>
# Stored data for player 65422 in ../data/65422.json
# Processing Player with ID 65423
# requesting http://www.playlivemanager.com/api/players/65423/stats/round
# <Response [200]>
# Stored data for player 65423 in ../data/65423.json
# Processing Player with ID 65424
# requesting http://www.playlivemanager.com/api/players/65424/stats/round
# <Response [200]>
# Stored data for player 65424 in ../data/65424.json
# Processing Player with ID 65425
# requesting http://www.playlivemanager.com/api/players/65425/stats/round
# <Response [200]>
# Stored data for player 65425 in ../data/65425.json
# Processing Player with ID 65426
# requesting http://www.playlivemanager.com/api/players/65426/stats/round
# <Response [200]>
# Stored data for player 65426 in ../data/65426.json
# Processing Player with ID 65427
# requesting http://www.playlivemanager.com/api/players/65427/stats/round
# <Response [200]>
# Stored data for player 65427 in ../data/65427.json
# Processing Player with ID 65428
# requesting http://www.playlivemanager.com/api/players/65428/stats/round
# <Response [200]>
# Stored data for player 65428 in ../data/65428.json
# Processing Player with ID 65429
# requesting http://www.playlivemanager.com/api/players/65429/stats/round
# <Response [200]>
# Stored data for player 65429 in ../data/65429.json
# Processing Player with ID 65430
# requesting http://www.playlivemanager.com/api/players/65430/stats/round
# <Response [200]>
# Stored data for player 65430 in ../data/65430.json
# Processing Player with ID 65431
# requesting http://www.playlivemanager.com/api/players/65431/stats/round
# <Response [200]>
# Stored data for player 65431 in ../data/65431.json
# Processing Player with ID 65432
# requesting http://www.playlivemanager.com/api/players/65432/stats/round
# <Response [200]>
# Stored data for player 65432 in ../data/65432.json
# Processing Player with ID 65433
# requesting http://www.playlivemanager.com/api/players/65433/stats/round
# <Response [200]>
# Stored data for player 65433 in ../data/65433.json
# Processing Player with ID 65434
# requesting http://www.playlivemanager.com/api/players/65434/stats/round
# <Response [200]>
# Stored data for player 65434 in ../data/65434.json
# Processing Player with ID 65435
# requesting http://www.playlivemanager.com/api/players/65435/stats/round
# <Response [200]>
# Stored data for player 65435 in ../data/65435.json
# Processing Player with ID 65436
# requesting http://www.playlivemanager.com/api/players/65436/stats/round
# <Response [200]>
# Stored data for player 65436 in ../data/65436.json
# Processing Player with ID 65437
# requesting http://www.playlivemanager.com/api/players/65437/stats/round
# <Response [200]>
# Stored data for player 65437 in ../data/65437.json
# Processing Player with ID 65438
# requesting http://www.playlivemanager.com/api/players/65438/stats/round
# <Response [200]>
# Stored data for player 65438 in ../data/65438.json
# Processing Player with ID 65439
# requesting http://www.playlivemanager.com/api/players/65439/stats/round
# <Response [200]>
# Stored data for player 65439 in ../data/65439.json
# Processing Player with ID 65440
# requesting http://www.playlivemanager.com/api/players/65440/stats/round
# <Response [200]>
# Stored data for player 65440 in ../data/65440.json
# Processing Player with ID 65441
# requesting http://www.playlivemanager.com/api/players/65441/stats/round
# <Response [200]>
# Stored data for player 65441 in ../data/65441.json
# Processing Player with ID 65442
# requesting http://www.playlivemanager.com/api/players/65442/stats/round
# <Response [200]>
# Stored data for player 65442 in ../data/65442.json
# Processing Player with ID 65443
# requesting http://www.playlivemanager.com/api/players/65443/stats/round
# <Response [200]>
# Stored data for player 65443 in ../data/65443.json
# Processing Player with ID 65444
# requesting http://www.playlivemanager.com/api/players/65444/stats/round
# <Response [200]>
# Stored data for player 65444 in ../data/65444.json
# Processing Player with ID 65445
# requesting http://www.playlivemanager.com/api/players/65445/stats/round
# <Response [200]>
# Stored data for player 65445 in ../data/65445.json
# Processing Player with ID 65446
# requesting http://www.playlivemanager.com/api/players/65446/stats/round
# <Response [200]>
# Stored data for player 65446 in ../data/65446.json
# Processing Player with ID 65447
# requesting http://www.playlivemanager.com/api/players/65447/stats/round
# <Response [200]>
# Stored data for player 65447 in ../data/65447.json
# Processing Player with ID 65448
# requesting http://www.playlivemanager.com/api/players/65448/stats/round
# <Response [200]>
# Stored data for player 65448 in ../data/65448.json
# Processing Player with ID 65449
# requesting http://www.playlivemanager.com/api/players/65449/stats/round
# <Response [200]>
# Stored data for player 65449 in ../data/65449.json
# Processing Player with ID 65450
# requesting http://www.playlivemanager.com/api/players/65450/stats/round
# <Response [200]>
# Stored data for player 65450 in ../data/65450.json
# Processing Player with ID 65451
# requesting http://www.playlivemanager.com/api/players/65451/stats/round
# <Response [200]>
# Stored data for player 65451 in ../data/65451.json
# Processing Player with ID 65452
# requesting http://www.playlivemanager.com/api/players/65452/stats/round
# <Response [200]>
# Stored data for player 65452 in ../data/65452.json
# Processing Player with ID 65453
# requesting http://www.playlivemanager.com/api/players/65453/stats/round
# <Response [200]>
# Stored data for player 65453 in ../data/65453.json
# Processing Player with ID 65454
# requesting http://www.playlivemanager.com/api/players/65454/stats/round
# <Response [200]>
# Stored data for player 65454 in ../data/65454.json
# Processing Player with ID 65455
# requesting http://www.playlivemanager.com/api/players/65455/stats/round
# <Response [200]>
# Stored data for player 65455 in ../data/65455.json
# Processing Player with ID 65456
# requesting http://www.playlivemanager.com/api/players/65456/stats/round
# <Response [200]>
# Stored data for player 65456 in ../data/65456.json
# Processing Player with ID 65457
# requesting http://www.playlivemanager.com/api/players/65457/stats/round
# <Response [200]>
# Stored data for player 65457 in ../data/65457.json
# Processing Player with ID 65458
# requesting http://www.playlivemanager.com/api/players/65458/stats/round
# <Response [200]>
# Stored data for player 65458 in ../data/65458.json
# Processing Player with ID 65459
# requesting http://www.playlivemanager.com/api/players/65459/stats/round
# <Response [200]>
# Stored data for player 65459 in ../data/65459.json
# Processing Player with ID 65460
# requesting http://www.playlivemanager.com/api/players/65460/stats/round
# <Response [200]>
# Stored data for player 65460 in ../data/65460.json
# Processing Player with ID 65461
# requesting http://www.playlivemanager.com/api/players/65461/stats/round
# <Response [200]>
# Stored data for player 65461 in ../data/65461.json
# Processing Player with ID 65462
# requesting http://www.playlivemanager.com/api/players/65462/stats/round
# <Response [200]>
# Stored data for player 65462 in ../data/65462.json
# Processing Player with ID 65463
# requesting http://www.playlivemanager.com/api/players/65463/stats/round
# <Response [200]>
# Stored data for player 65463 in ../data/65463.json
# Processing Player with ID 65464
# requesting http://www.playlivemanager.com/api/players/65464/stats/round
# <Response [200]>
# Stored data for player 65464 in ../data/65464.json
# Processing Player with ID 65465
# requesting http://www.playlivemanager.com/api/players/65465/stats/round
# <Response [200]>
# Stored data for player 65465 in ../data/65465.json
# Processing Player with ID 65466
# requesting http://www.playlivemanager.com/api/players/65466/stats/round
# <Response [200]>
# Stored data for player 65466 in ../data/65466.json
# Processing Player with ID 65467
# requesting http://www.playlivemanager.com/api/players/65467/stats/round
# <Response [200]>
# Stored data for player 65467 in ../data/65467.json
# Processing Player with ID 65468
# requesting http://www.playlivemanager.com/api/players/65468/stats/round
# <Response [200]>
# Stored data for player 65468 in ../data/65468.json
# Processing Player with ID 65469
# requesting http://www.playlivemanager.com/api/players/65469/stats/round
# <Response [200]>
# Stored data for player 65469 in ../data/65469.json
# Processing Player with ID 65470
# requesting http://www.playlivemanager.com/api/players/65470/stats/round
# <Response [200]>
# Stored data for player 65470 in ../data/65470.json
# Processing Player with ID 65471
# requesting http://www.playlivemanager.com/api/players/65471/stats/round
# <Response [200]>
# Stored data for player 65471 in ../data/65471.json
# Processing Player with ID 65472
# requesting http://www.playlivemanager.com/api/players/65472/stats/round
# <Response [200]>
# Stored data for player 65472 in ../data/65472.json
# Processing Player with ID 65473
# requesting http://www.playlivemanager.com/api/players/65473/stats/round
# <Response [200]>
# Stored data for player 65473 in ../data/65473.json
# Processing Player with ID 65474
# requesting http://www.playlivemanager.com/api/players/65474/stats/round
# <Response [200]>
# Stored data for player 65474 in ../data/65474.json
# Processing Player with ID 65475
# requesting http://www.playlivemanager.com/api/players/65475/stats/round
# <Response [200]>
# Stored data for player 65475 in ../data/65475.json
# Processing Player with ID 65476
# requesting http://www.playlivemanager.com/api/players/65476/stats/round
# <Response [200]>
# Stored data for player 65476 in ../data/65476.json
# Processing Player with ID 65477
# requesting http://www.playlivemanager.com/api/players/65477/stats/round
# <Response [200]>
# Stored data for player 65477 in ../data/65477.json
# Processing Player with ID 65478
# requesting http://www.playlivemanager.com/api/players/65478/stats/round
# <Response [200]>
# Stored data for player 65478 in ../data/65478.json
# ...
# <Response [200]>
# Stored data for player 65624 in ../data/65624.json
# Processing Player with ID 65625
# requesting http://www.playlivemanager.com/api/players/65625/stats/round
# <Response [200]>
# Stored data for player 65625 in ../data/65625.json
# Processing Player with ID 65626
# requesting http://www.playlivemanager.com/api/players/65626/stats/round
# <Response [200]>
# Stored data for player 65626 in ../data/65626.json
# Processing Player with ID 65627
# requesting http://www.playlivemanager.com/api/players/65627/stats/round
# <Response [200]>
# Stored data for player 65627 in ../data/65627.json
# Processing Player with ID 65628
# requesting http://www.playlivemanager.com/api/players/65628/stats/round
# <Response [200]>
# Stored data for player 65628 in ../data/65628.json
# Processing Player with ID 65629
# requesting http://www.playlivemanager.com/api/players/65629/stats/round
# <Response [200]>
# Stored data for player 65629 in ../data/65629.json
# Processing Player with ID 65630
# requesting http://www.playlivemanager.com/api/players/65630/stats/round
# <Response [200]>
# Stored data for player 65630 in ../data/65630.json
# Processing Player with ID 65631
# requesting http://www.playlivemanager.com/api/players/65631/stats/round
# <Response [200]>
# Stored data for player 65631 in ../data/65631.json
# Processing Player with ID 65632
# requesting http://www.playlivemanager.com/api/players/65632/stats/round
# <Response [200]>
# Stored data for player 65632 in ../data/65632.json
# Processing Player with ID 65633
# requesting http://www.playlivemanager.com/api/players/65633/stats/round
# <Response [200]>
# Stored data for player 65633 in ../data/65633.json
# Processing Player with ID 65634
# requesting http://www.playlivemanager.com/api/players/65634/stats/round
# <Response [200]>
# Stored data for player 65634 in ../data/65634.json
# Processing Player with ID 65635
# requesting http://www.playlivemanager.com/api/players/65635/stats/round
# <Response [200]>
# Stored data for player 65635 in ../data/65635.json
# Processing Player with ID 65636
# requesting http://www.playlivemanager.com/api/players/65636/stats/round
# <Response [200]>
# Stored data for player 65636 in ../data/65636.json
# Processing Player with ID 65637
# requesting http://www.playlivemanager.com/api/players/65637/stats/round
# <Response [200]>
# Stored data for player 65637 in ../data/65637.json
# Processing Player with ID 65638
# requesting http://www.playlivemanager.com/api/players/65638/stats/round
# <Response [200]>
# Stored data for player 65638 in ../data/65638.json
# Processing Player with ID 65639
# requesting http://www.playlivemanager.com/api/players/65639/stats/round
# <Response [200]>
# Stored data for player 65639 in ../data/65639.json
# Processing Player with ID 65640
# requesting http://www.playlivemanager.com/api/players/65640/stats/round
# <Response [200]>
# Stored data for player 65640 in ../data/65640.json
# Processing Player with ID 65641
# requesting http://www.playlivemanager.com/api/players/65641/stats/round
# <Response [200]>
# Stored data for player 65641 in ../data/65641.json
# Processing Player with ID 65642
# requesting http://www.playlivemanager.com/api/players/65642/stats/round
# <Response [200]>
# Stored data for player 65642 in ../data/65642.json
# Processing Player with ID 65643
# requesting http://www.playlivemanager.com/api/players/65643/stats/round
# <Response [200]>
# Stored data for player 65643 in ../data/65643.json
# Processing Player with ID 65644
# requesting http://www.playlivemanager.com/api/players/65644/stats/round
# <Response [200]>
# Stored data for player 65644 in ../data/65644.json
# Processing Player with ID 65645
# requesting http://www.playlivemanager.com/api/players/65645/stats/round
# <Response [200]>
# Stored data for player 65645 in ../data/65645.json
# Processing Player with ID 65646
# requesting http://www.playlivemanager.com/api/players/65646/stats/round
# <Response [200]>
# Stored data for player 65646 in ../data/65646.json
# Processing Player with ID 65647
# requesting http://www.playlivemanager.com/api/players/65647/stats/round
# <Response [200]>
# Stored data for player 65647 in ../data/65647.json
# Processing Player with ID 65648
# requesting http://www.playlivemanager.com/api/players/65648/stats/round
# <Response [200]>
# Stored data for player 65648 in ../data/65648.json
# Processing Player with ID 65649
# requesting http://www.playlivemanager.com/api/players/65649/stats/round
# <Response [200]>
# Stored data for player 65649 in ../data/65649.json
# Processing Player with ID 65650
# requesting http://www.playlivemanager.com/api/players/65650/stats/round
# <Response [200]>
# Stored data for player 65650 in ../data/65650.json
# Processing Player with ID 65651
# requesting http://www.playlivemanager.com/api/players/65651/stats/round
# <Response [200]>
# Stored data for player 65651 in ../data/65651.json
# Processing Player with ID 65652
# requesting http://www.playlivemanager.com/api/players/65652/stats/round
# <Response [200]>
# Stored data for player 65652 in ../data/65652.json
# Processing Player with ID 65653
# requesting http://www.playlivemanager.com/api/players/65653/stats/round
# <Response [200]>
# Stored data for player 65653 in ../data/65653.json
# Processing Player with ID 65654
# requesting http://www.playlivemanager.com/api/players/65654/stats/round
# <Response [200]>
# Stored data for player 65654 in ../data/65654.json
# Processing Player with ID 65655
# requesting http://www.playlivemanager.com/api/players/65655/stats/round
# <Response [200]>
# Stored data for player 65655 in ../data/65655.json
# Processing Player with ID 65656
# requesting http://www.playlivemanager.com/api/players/65656/stats/round
# <Response [200]>
# Stored data for player 65656 in ../data/65656.json
# Processing Player with ID 65657
# requesting http://www.playlivemanager.com/api/players/65657/stats/round
# <Response [200]>
# Stored data for player 65657 in ../data/65657.json
# Processing Player with ID 65658
# requesting http://www.playlivemanager.com/api/players/65658/stats/round
# <Response [200]>
# Stored data for player 65658 in ../data/65658.json
# Processing Player with ID 65659
# requesting http://www.playlivemanager.com/api/players/65659/stats/round
# <Response [200]>
# Stored data for player 65659 in ../data/65659.json
# Processing Player with ID 65660
# requesting http://www.playlivemanager.com/api/players/65660/stats/round
# <Response [200]>
# Stored data for player 65660 in ../data/65660.json
# Processing Player with ID 65661
# requesting http://www.playlivemanager.com/api/players/65661/stats/round
# <Response [200]>
# Stored data for player 65661 in ../data/65661.json
# Processing Player with ID 65662
# requesting http://www.playlivemanager.com/api/players/65662/stats/round
# <Response [200]>
# Stored data for player 65662 in ../data/65662.json
# Processing Player with ID 65663
# requesting http://www.playlivemanager.com/api/players/65663/stats/round
# <Response [200]>
# Stored data for player 65663 in ../data/65663.json
# Processing Player with ID 65664
# requesting http://www.playlivemanager.com/api/players/65664/stats/round
# <Response [200]>
# Stored data for player 65664 in ../data/65664.json
# Processing Player with ID 65665
# requesting http://www.playlivemanager.com/api/players/65665/stats/round
# <Response [200]>
# Stored data for player 65665 in ../data/65665.json
# Processing Player with ID 65666
# requesting http://www.playlivemanager.com/api/players/65666/stats/round
# <Response [200]>
# Stored data for player 65666 in ../data/65666.json
# Processing Player with ID 65667
# requesting http://www.playlivemanager.com/api/players/65667/stats/round
# <Response [200]>
# Stored data for player 65667 in ../data/65667.json
# Processing Player with ID 65668
# requesting http://www.playlivemanager.com/api/players/65668/stats/round
# <Response [200]>
# Stored data for player 65668 in ../data/65668.json
# Processing Player with ID 65669
# requesting http://www.playlivemanager.com/api/players/65669/stats/round
# <Response [200]>
# Stored data for player 65669 in ../data/65669.json
# Processing Player with ID 65670
# requesting http://www.playlivemanager.com/api/players/65670/stats/round
# <Response [200]>
# Stored data for player 65670 in ../data/65670.json
# Processing Player with ID 65671
# requesting http://www.playlivemanager.com/api/players/65671/stats/round
# <Response [200]>
# Stored data for player 65671 in ../data/65671.json
# Processing Player with ID 65672
# requesting http://www.playlivemanager.com/api/players/65672/stats/round
# <Response [200]>
# Stored data for player 65672 in ../data/65672.json
# Processing Player with ID 65673
# requesting http://www.playlivemanager.com/api/players/65673/stats/round
# <Response [200]>
# Stored data for player 65673 in ../data/65673.json
# Processing Player with ID 65674
# requesting http://www.playlivemanager.com/api/players/65674/stats/round
# <Response [200]>
# Stored data for player 65674 in ../data/65674.json
# Processing Player with ID 65675
# requesting http://www.playlivemanager.com/api/players/65675/stats/round
# <Response [200]>
# Stored data for player 65675 in ../data/65675.json
# Processing Player with ID 65676
# requesting http://www.playlivemanager.com/api/players/65676/stats/round
# <Response [200]>
# Stored data for player 65676 in ../data/65676.json
# Processing Player with ID 65677
# requesting http://www.playlivemanager.com/api/players/65677/stats/round
# <Response [200]>
# Stored data for player 65677 in ../data/65677.json
# Processing Player with ID 65678
# requesting http://www.playlivemanager.com/api/players/65678/stats/round
# <Response [200]>
# Stored data for player 65678 in ../data/65678.json
# Processing Player with ID 65679
# requesting http://www.playlivemanager.com/api/players/65679/stats/round
# <Response [200]>
# Stored data for player 65679 in ../data/65679.json
# Processing Player with ID 65680
# requesting http://www.playlivemanager.com/api/players/65680/stats/round
# <Response [200]>
# Stored data for player 65680 in ../data/65680.json
# Processing Player with ID 65681
# requesting http://www.playlivemanager.com/api/players/65681/stats/round
# <Response [200]>
# Stored data for player 65681 in ../data/65681.json
# Processing Player with ID 65682
# requesting http://www.playlivemanager.com/api/players/65682/stats/round
# <Response [200]>
# Stored data for player 65682 in ../data/65682.json
# Processing Player with ID 65683
# requesting http://www.playlivemanager.com/api/players/65683/stats/round
# <Response [200]>
# Stored data for player 65683 in ../data/65683.json
# Processing Player with ID 65684
# requesting http://www.playlivemanager.com/api/players/65684/stats/round
# <Response [200]>
# Stored data for player 65684 in ../data/65684.json
# Processing Player with ID 65685
# requesting http://www.playlivemanager.com/api/players/65685/stats/round
# <Response [200]>
# Stored data for player 65685 in ../data/65685.json
# Processing Player with ID 65686
# requesting http://www.playlivemanager.com/api/players/65686/stats/round
# <Response [200]>
# Stored data for player 65686 in ../data/65686.json
# Processing Player with ID 65687
# requesting http://www.playlivemanager.com/api/players/65687/stats/round
# <Response [200]>
# Stored data for player 65687 in ../data/65687.json
# Processing Player with ID 65688
# requesting http://www.playlivemanager.com/api/players/65688/stats/round
# <Response [200]>
# Stored data for player 65688 in ../data/65688.json
# Processing Player with ID 65689
# requesting http://www.playlivemanager.com/api/players/65689/stats/round
# <Response [200]>
# Stored data for player 65689 in ../data/65689.json
# Processing Player with ID 65690
# requesting http://www.playlivemanager.com/api/players/65690/stats/round
# <Response [200]>
# Stored data for player 65690 in ../data/65690.json
# Processing Player with ID 65691
# requesting http://www.playlivemanager.com/api/players/65691/stats/round
# <Response [200]>
# Stored data for player 65691 in ../data/65691.json
# Processing Player with ID 65692
# requesting http://www.playlivemanager.com/api/players/65692/stats/round
# <Response [200]>
# Stored data for player 65692 in ../data/65692.json
# Processing Player with ID 65693
# requesting http://www.playlivemanager.com/api/players/65693/stats/round
# <Response [200]>
# Stored data for player 65693 in ../data/65693.json
# Processing Player with ID 65694
# requesting http://www.playlivemanager.com/api/players/65694/stats/round
# <Response [200]>
# Stored data for player 65694 in ../data/65694.json
# Processing Player with ID 65695
# requesting http://www.playlivemanager.com/api/players/65695/stats/round
# <Response [200]>
# Stored data for player 65695 in ../data/65695.json
# Processing Player with ID 65696
# requesting http://www.playlivemanager.com/api/players/65696/stats/round
# <Response [200]>
# Stored data for player 65696 in ../data/65696.json
# Processing Player with ID 65697
# requesting http://www.playlivemanager.com/api/players/65697/stats/round
# <Response [200]>
# Stored data for player 65697 in ../data/65697.json
# Processing Player with ID 65698
# requesting http://www.playlivemanager.com/api/players/65698/stats/round
# <Response [200]>
# Stored data for player 65698 in ../data/65698.json
# Processing Player with ID 65699
# requesting http://www.playlivemanager.com/api/players/65699/stats/round
# <Response [200]>
# Stored data for player 65699 in ../data/65699.json
# Processing Player with ID 65700
# requesting http://www.playlivemanager.com/api/players/65700/stats/round
# <Response [200]>
# Stored data for player 65700 in ../data/65700.json
# Processing Player with ID 65701
# requesting http://www.playlivemanager.com/api/players/65701/stats/round
# <Response [200]>
# Stored data for player 65701 in ../data/65701.json
# Processing Player with ID 65702
# requesting http://www.playlivemanager.com/api/players/65702/stats/round
# <Response [200]>
# Stored data for player 65702 in ../data/65702.json
# Processing Player with ID 65703
# requesting http://www.playlivemanager.com/api/players/65703/stats/round
# <Response [200]>
# Stored data for player 65703 in ../data/65703.json
# Processing Player with ID 65704
# requesting http://www.playlivemanager.com/api/players/65704/stats/round
# <Response [200]>
# Stored data for player 65704 in ../data/65704.json
# Processing Player with ID 65705
# requesting http://www.playlivemanager.com/api/players/65705/stats/round
# <Response [200]>
# Stored data for player 65705 in ../data/65705.json
# Processing Player with ID 65706
# requesting http://www.playlivemanager.com/api/players/65706/stats/round
# <Response [200]>
# Stored data for player 65706 in ../data/65706.json
# Processing Player with ID 65707
# requesting http://www.playlivemanager.com/api/players/65707/stats/round
# <Response [200]>
# Stored data for player 65707 in ../data/65707.json
# Processing Player with ID 65708
# requesting http://www.playlivemanager.com/api/players/65708/stats/round
# <Response [200]>
# Stored data for player 65708 in ../data/65708.json
# Processing Player with ID 65709
# requesting http://www.playlivemanager.com/api/players/65709/stats/round
# <Response [200]>
# Stored data for player 65709 in ../data/65709.json
# Processing Player with ID 65710
# requesting http://www.playlivemanager.com/api/players/65710/stats/round
# <Response [200]>
# Stored data for player 65710 in ../data/65710.json
# Processing Player with ID 65711
# requesting http://www.playlivemanager.com/api/players/65711/stats/round
# <Response [200]>
# Stored data for player 65711 in ../data/65711.json
# Processing Player with ID 65712
# requesting http://www.playlivemanager.com/api/players/65712/stats/round
# <Response [200]>
# Stored data for player 65712 in ../data/65712.json
# Processing Player with ID 65713
# requesting http://www.playlivemanager.com/api/players/65713/stats/round
# <Response [200]>
# Stored data for player 65713 in ../data/65713.json
# Processing Player with ID 65714
# requesting http://www.playlivemanager.com/api/players/65714/stats/round
# <Response [200]>
# Stored data for player 65714 in ../data/65714.json
# Processing Player with ID 65715
# requesting http://www.playlivemanager.com/api/players/65715/stats/round
# <Response [200]>
# Stored data for player 65715 in ../data/65715.json
# Processing Player with ID 65716
# requesting http://www.playlivemanager.com/api/players/65716/stats/round
# <Response [200]>
# Stored data for player 65716 in ../data/65716.json
# Processing Player with ID 65717
# requesting

# %%
transform_data()
# Out:
# Deleting old files
# Begin transforming data
# Processing ../data/64400.json
# Added ../data/64400.json to ../data/all.json
# Processing ../data/64401.json
# Added ../data/64401.json to ../data/all.json
# Processing ../data/64402.json
# Added ../data/64402.json to ../data/all.json
# Processing ../data/64403.json
# Added ../data/64403.json to ../data/all.json
# Processing ../data/64404.json
# Added ../data/64404.json to ../data/all.json
# Processing ../data/64405.json
# Added ../data/64405.json to ../data/all.json
# Processing ../data/64406.json
# Added ../data/64406.json to ../data/all.json
# Processing ../data/64407.json
# Added ../data/64407.json to ../data/all.json
# Processing ../data/64408.json
# Added ../data/64408.json to ../data/all.json
# Processing ../data/64409.json
# Added ../data/64409.json to ../data/all.json
# Processing ../data/64410.json
# Added ../data/64410.json to ../data/all.json
# Processing ../data/64411.json
# Added ../data/64411.json to ../data/all.json
# Processing ../data/64412.json
# Added ../data/64412.json to ../data/all.json
# Processing ../data/64413.json
# Added ../data/64413.json to ../data/all.json
# Processing ../data/64414.json
# Added ../data/64414.json to ../data/all.json
# Processing ../data/64415.json
# Added ../data/64415.json to ../data/all.json
# Processing ../data/64416.json
# Added ../data/64416.json to ../data/all.json
# Processing ../data/64417.json
# Added ../data/64417.json to ../data/all.json
# Processing ../data/64418.json
# Added ../data/64418.json to ../data/all.json
# Processing ../data/64419.json
# Added ../data/64419.json to ../data/all.json
# Processing ../data/64420.json
# Added ../data/64420.json to ../data/all.json
# Processing ../data/64421.json
# Added ../data/64421.json to ../data/all.json
# Processing ../data/64422.json
# Added ../data/64422.json to ../data/all.json
# Processing ../data/64423.json
# Added ../data/64423.json to ../data/all.json
# Processing ../data/64424.json
# Added ../data/64424.json to ../data/all.json
# Processing ../data/64425.json
# Added ../data/64425.json to ../data/all.json
# Processing ../data/64426.json
# Added ../data/64426.json to ../data/all.json
# Processing ../data/64427.json
# Added ../data/64427.json to ../data/all.json
# Processing ../data/64428.json
# Added ../data/64428.json to ../data/all.json
# Processing ../data/64429.json
# Added ../data/64429.json to ../data/all.json
# Processing ../data/64430.json
# Added ../data/64430.json to ../data/all.json
# Processing ../data/64431.json
# Added ../data/64431.json to ../data/all.json
# Processing ../data/64432.json
# Added ../data/64432.json to ../data/all.json
# Processing ../data/64433.json
# Added ../data/64433.json to ../data/all.json
# Processing ../data/64434.json
# Added ../data/64434.json to ../data/all.json
# Processing ../data/64435.json
# Added ../data/64435.json to ../data/all.json
# Processing ../data/64436.json
# Added ../data/64436.json to ../data/all.json
# Processing ../data/64437.json
# Added ../data/64437.json to ../data/all.json
# Processing ../data/64438.json
# Added ../data/64438.json to ../data/all.json
# Processing ../data/64439.json
# Added ../data/64439.json to ../data/all.json
# Processing ../data/64440.json
# Added ../data/64440.json to ../data/all.json
# Processing ../data/64441.json
# Added ../data/64441.json to ../data/all.json
# Processing ../data/64442.json
# Added ../data/64442.json to ../data/all.json
# Processing ../data/64443.json
# Added ../data/64443.json to ../data/all.json
# Processing ../data/64444.json
# Added ../data/64444.json to ../data/all.json
# Processing ../data/64445.json
# Added ../data/64445.json to ../data/all.json
# Processing ../data/64446.json
# Added ../data/64446.json to ../data/all.json
# Processing ../data/64447.json
# Added ../data/65007.json to ../data/all.json
# Processing ../data/65008.json
# Added ../data/65008.json to ../data/all.json
# Processing ../data/65009.json
# Added ../data/65009.json to ../data/all.json
# Processing ../data/65010.json
# Added ../data/65010.json to ../data/all.json
# Processing ../data/65011.json
# Added ../data/65011.json to ../data/all.json
# Processing ../data/65012.json
# Added ../data/65012.json to ../data/all.json
# Processing ../data/65013.json
# Added ../data/65013.json to ../data/all.json
# Processing ../data/65014.json
# Added ../data/65014.json to ../data/all.json
# Processing ../data/65015.json
# Added ../data/65015.json to ../data/all.json
# Processing ../data/65016.json
# Added ../data/65016.json to ../data/all.json
# Processing ../data/65017.json
# Added ../data/65017.json to ../data/all.json
# Processing ../data/65018.json
# Added ../data/65018.json to ../data/all.json
# Processing ../data/65019.json
# Added ../data/65019.json to ../data/all.json
# Processing ../data/65020.json
# Added ../data/65020.json to ../data/all.json
# Processing ../data/65021.json
# Added ../data/65021.json to ../data/all.json
# Processing ../data/65022.json
# Added ../data/65022.json to ../data/all.json
# Processing ../data/65023.json
# Added ../data/65023.json to ../data/all.json
# Processing ../data/65024.json
# Added ../data/65024.json to ../data/all.json
# Processing ../data/65025.json
# Added ../data/65025.json to ../data/all.json
# Processing ../data/65026.json
# Added ../data/65026.json to ../data/all.json
# Processing ../data/65027.json
# Added ../data/65027.json to ../data/all.json
# Processing ../data/65028.json
# Added ../data/65028.json to ../data/all.json
# Processing ../data/65029.json
# Added ../data/65029.json to ../data/all.json
# Processing ../data/65030.json
# Added ../data/65030.json to ../data/all.json
# Processing ../data/65031.json
# Added ../data/65031.json to ../data/all.json
# Processing ../data/65032.json
# Added ../data/65032.json to ../data/all.json
# Processing ../data/65033.json
# Added ../data/65033.json to ../data/all.json
# Processing ../data/65034.json
# Added ../data/65034.json to ../data/all.json
# Processing ../data/65035.json
# Added ../data/65035.json to ../data/all.json
# Processing ../data/65036.json
# Added ../data/65036.json to ../data/all.json
# Processing ../data/65037.json
# Added ../data/65037.json to ../data/all.json
# Processing ../data/65038.json
# Added ../data/65038.json to ../data/all.json
# Processing ../data/65039.json
# ...
# Processing ../data/66588.json
# Added ../data/66588.json to ../data/all.json
# Processing ../data/66589.json
# Added ../data/66589.json to ../data/all.json
# Processing ../data/66590.json
# Added ../data/66590.json to ../data/all.json
# Processing ../data/66591.json
# Added ../data/66591.json to ../data/all.json
# Processing ../data/66592.json
# Added ../data/66592.json to ../data/all.json
# Processing ../data/66593.json
# Added ../data/66593.json to ../data/all.json
# Processing ../data/66594.json
# Added ../data/66594.json to ../data/all.json
# Processing ../data/66595.json
# Added ../data/66595.json to ../data/all.json
# Processing ../data/66596.json
# Added ../data/66596.json to ../data/all.json
# Processing ../data/66597.json
# Added ../data/66597.json to ../data/all.json
# Processing ../data/66598.json
# Added ../data/66598.json to ../data/all.json
# Processing ../data/66599.json
# Added ../data/66599.json to ../data/all.json
# Processing ../data/66600.json
# Added ../data/66600.json to ../data/all.json
# Processing ../data/66601.json
# Added ../data/66601.json to ../data/all.json
# Processing ../data/66602.json
# Added ../data/66602.json to ../data/all.json
# Processing ../data/66603.json
# Added ../data/66603.json to ../data/all.json
# Processing ../data/66604.json
# Added ../data/66604.json to ../data/all.json
# Processing ../data/66605.json
# Added ../data/66605.json to ../data/all.json
# Processing ../data/66606.json
# Added ../data/66606.json to ../data/all.json
# Processing ../data/66607.json
# Added ../data/66607.json to ../data/all.json
# Processing ../data/66608.json
# Added ../data/66608.json to ../data/all.json
# Processing ../data/66609.json
# Added ../data/66609.json to ../data/all.json
# Processing ../data/66610.json
# Added ../data/66610.json to ../data/all.json
# Processing ../data/66611.json
# Added ../data/66611.json to ../data/all.json
# Processing ../data/66612.json
# Added ../data/66612.json to ../data/all.json
# Processing ../data/66613.json
# Added ../data/66613.json to ../data/all.json
# Processing ../data/66614.json
# Added ../data/66614.json to ../data/all.json
# Processing ../data/66615.json
# Added ../data/66615.json to ../data/all.json
# Processing ../data/66616.json
# Added ../data/66616.json to ../data/all.json
# Processing ../data/66617.json
# Added ../data/66617.json to ../data/all.json
# Processing ../data/66618.json
# Added ../data/66618.json to ../data/all.json
# Processing ../data/66619.json
# Added ../data/66619.json to ../data/all.json
# Processing ../data/66620.json
# Added ../data/66620.json to ../data/all.json
# Processing ../data/66621.json
# Added ../data/66621.json to ../data/all.json
# Processing ../data/66622.json
# Added ../data/66622.json to ../data/all.json
# Processing ../data/66623.json
# Added ../data/66623.json to ../data/all.json
# Processing ../data/66624.json
# Added ../data/66624.json to ../data/all.json
# Processing ../data/66625.json
# Added ../data/66625.json to ../data/all.json
# Processing ../data/66626.json
# Added ../data/66626.json to ../data/all.json
# Processing ../data/66627.json
# Added ../data/66627.json to ../data/all.json
# Processing ../data/66628.json
# Added ../data/66628.json to ../data/all.json
# Processing ../data/66629.json
# Added ../data/66629.json to ../data/all.json
# Processing ../data/66630.json
# Added ../data/66630.json to ../data/all.json
# Processing ../data/66631.json
# Added ../data/66631.json to ../data/all.json
# Processing ../data/66632.json
# Added ../data/66632.json to ../data/all.json
# Processing ../data/66633.json
# Added ../data/66633.json to ../data/all.json
# Processing ../data/66634.json
# Added ../data/66634.json to ../data/all.json
# Processing ../data/66635.json
# Added ../data/66635.json to ../data/all.json
# Processing ../data/66636.json
# Added ../data/66636.json to ../data/all.json
# Processing ../data/66637.json
# Added ../data/66637.json to ../data/all.json
# Processing ../data/66638.json
# Added ../data/66638.json to ../data/all.json
# Processing ../data/66639.json
# Added ../data/66639.json to ../data/all.json
# Processing ../data/66640.json
# Added ../data/66640.json to ../data/all.json
# Processing ../data/66641.json
# Added ../data/66641.json to ../data/all.json
# Processing ../data/66642.json
# Added ../data/66642.json to ../data/all.json
# Processing ../data/66643.json
# Added ../data/66643.json to ../data/all.json
# Processing ../data/66644.json
# Added ../data/66644.json to ../data/all.json
# Processing ../data/66645.json
# Added ../data/66645.json to ../data/all.json
# Processing ../data/66646.json
# Added ../data/66646.json to ../data/all.json
# Processing ../data/66647.json
# Added ../data/66647.json to ../data/all.json
# Processing ../data/66648.json
# Added ../data/66648.json to ../data/all.json
# Processing ../data/66649.json
# Added ../data/66649.json to ../data/all.json
# Processing ../data/66650.json
# Added ../data/66650.json to ../data/all.json
# Processing ../data/66651.json
# Added ../data/66651.json to ../data/all.json
# Processing ../data/66652.json
# Added ../data/66652.json to ../data/all.json
# Processing ../data/66653.json
# Added ../data/66653.json to ../data/all.json
# Processing ../data/66654.json
# Added ../data/66654.json to ../data/all.json
# Processing ../data/66655.json
# Added ../data/66655.json to ../data/all.json
# Processing ../data/66656.json
# Added ../data/66656.json to ../data/all.json
# Processing ../data/66657.json
# Added ../data/66657.json to ../data/all.json
# Processing ../data/66658.json
# Added ../data/66658.json to ../data/all.json
# Processing ../data/66659.json
# Added ../data/66659.json to ../data/all.json
# Processing ../data/66660.json
# Added ../data/66660.json to ../data/all.json
# Processing ../data/66661.json
# Added ../data/66661.json to ../data/all.json
# Processing ../data/66662.json
# Added ../data/66662.json to ../data/all.json
# Processing ../data/66663.json
# Added ../data/66663.json to ../data/all.json
# Processing ../data/66664.json
# Added ../data/66664.json to ../data/all.json
# Processing ../data/66665.json
# Added ../data/66665.json to ../data/all.json
# Processing ../data/66666.json
# Added ../data/66666.json to ../data/all.json
# Processing ../data/66667.json
# Added ../data/66667.json to ../data/all.json
# Processing ../data/66668.json
# Added ../data/66668.json to ../data/all.json
# Processing ../data/66669.json
# Added ../data/66669.json to ../data/all.json
# Processing ../data/66670.json
# Added ../data/66670.json to ../data/all.json
# Processing ../data/66671.json
# Added ../data/66671.json to ../data/all.json
# Processing ../data/66672.json
# Added ../data/66672.json to ../data/all.json
# Processing ../data/66673.json
# Added ../data/66673.json to ../data/all.json
# Processing ../data/66674.json
# Added ../data/66674.json to ../data/all.json
# Processing ../data/66675.json
# Added ../data/66675.json to ../data/all.json
# Processing ../data/66676.json
# Added ../data/66676.json to ../data/all.json
# Processing ../data/66677.json
# Added ../data/66677.json to ../data/all.json
# Processing ../data/66678.json
# Added ../data/66678.json to ../data/all.json
# Processing ../data/66679.json
# Added ../data/66679.json to ../data/all.json
# Processing ../data/66680.json
# Added ../data/66680.json to ../data/all.json
# Processing ../data/66681.json
# Added ../data/66681.json to ../data/all.json
# Processing ../data/66682.json
# Added ../data/66682.json to ../data/all.json
# Processing ../data/66683.json
# Added ../data/66683.json to ../data/all.json
# Processing ../data/66684.json
# Added ../data/66684.json to ../data/all.json
# Processing ../data/66685.json
# Added ../data/66685.json to ../data/all.json
# Processing ../data/66686.json
# Added ../data/66686.json to ../data/all.json
# Processing ../data/66687.json
# Added ../data/66687.json to ../data/all.json
# Processing ../data/66688.json
# Added ../data/66688.json to ../data/all.json
# Processing ../data/66689.json
# Added ../data/66689.json to ../data/all.json
# Processing ../data/66690.json
# Added ../data/66690.json to ../data/all.json
# Processing ../data/66691.json
# Added ../data/66691.json to ../data/all.json
# Processing ../data/66692.json
# Added ../data/66692.json to ../data/all.json
# Processing ../data/66693.json
# Added ../data/66693.json to ../data/all.json
# Processing ../data/66694.json
# Added ../data/66694.json to ../data/all.json
# Processing ../data/66695.json
# Added ../data/66695.json to ../data/all.json
# Processing ../data/66696.json
# Added ../data/66696.json to ../data/all.json
# Processing ../data/66697.json
# Added ../data/66697.json to ../data/all.json
# Processing ../data/66698.json
# Added ../data/66698.json to ../data/all.json
# Processing ../data/66699.json
# Added ../data/66699.json to ../data/all.json
# Processing ../data/66700.json
# Added ../data/66700.json to ../data/all.json
# Processing ../data/66701.json
# Added ../data/66701.json to ../data/all.json
# Processing ../data/66702.json
# Added ../data/66702.json to ../data/all.json
# Processing ../data/66703.json
# Added ../data/66703.json to ../data/all.json
# Processing ../data/66704.json
# Added ../data/66704.json to ../data/all.json
# Processing ../data/66705.json
# Added ../data/66705.json to ../data/all.json
# Processing ../data/66706.json
# Added ../data/66706.json to ../data/all.json
# Processing ../data/66707.json
# Added ../data/66707.json to ../data/all.json
# Processing ../data/66708.json
# Added ../data/66708.json to ../data/all.json
# Processing ../data/66709.json
# Added ../data/66709.json to ../data/all.json
# Processing ../data/66710.json
# Added ../data/66710.json to ../data/all.json
# Processing ../data/66711.json
# Added ../data/66711.json to ../data/all.json
# Processing ../data/66712.json
# Added ../data/66712.json to ../data/all.json
# Processing ../data/66713.json
# Added ../data/66713.json to ../data/all.json
# Processing ../data/66714.json
# Added ../data/66714.json to ../data/all.json
# Processing ../data/66715.json
# Added ../data/66715.json to ../data/all.json
# Processing ../data/66716.json
# Added ../data/66716.json to ../data/all.json
# Processing ../data/66717.json
# Added ../data/66717.json to ../data/all.json
# Processing ../data/66718.json
# Added ../data/66718.json to ../data/all.json
# Processing ../data/66719.json
# Added ../data/66719.json to ../data/all.json
# Processing ../data/66720.json
# Added ../data/66720.json to ../data/all.json
# Processing ../data/66721.json
# Added ../data/66721.json to ../data/all.json
# Processing ../data/66722.json
# Added ../data/66722.json to ../data/all.json
# Processing ../data/66723.json
# Added ../data/66723.json to ../data/all.json
# Processing ../data/66724.json
# Added ../data/66724.json to ../data/all.json
# Processing ../data/66725.json
# Added ../data/66725.json to ../data/all.json
# Processing ../data/66726.json
# Added ../data/66726.json to ../data/all.json
# Processing ../data/66727.json
# Added ../data/66727.json to ../data/all.json
# Processing ../data/66728.json
# Added ../data/66728.json to ../data/all.json
# Processing ../data/66729.json
# Added ../data/66729.json to ../data/all.json
# Processing ../data/66730.json
# Added ../data/66730.json to ../data/all.json
# Processing ../data/66731.json
# Added ../data/66731.json to ../data/all.json
# Processing ../data/66732.json
# Added ../data/66732.json to ../data/all.json
# Processing ../data/66733.json
# Added ../data/66733.json to ../data/all.json
# Processing ../data/66734.json
# Added ../data/66734.json to ../data/all.json
# Processing ../data/66735.json
# Added ../data/66735.json to ../data/all.json
# Processing ../data/66736.json
# Added ../data/66736.json to ../data/all.json
# Processing ../data/66737.json
# Added ../data/66737.json to ../data/all.json
# Processing ../data/66738.json
# Added ../data/66738.json to ../data/all.json
# Processing ../data/66739.json
# Added ../data/66739.json to ../data/all.json
# Processing ../data/66740.json
# Added ../data/66740.json to ../data/all.json
# Processing ../data/66741.json
# Added ../data/66741.json to ../data/all.json
# Processing ../data/66742.json
# Added ../data/66742.json to ../data/all.json
# Processing ../data/66743.json
# Added ../data/66743.json to ../data/all.json
# Processing ../data/66744.json
# Added ../data/66744.json to ../data/all.json
# Processing ../data/66745.json
# Added ../data/66745.json to ../data/all.json
# Processing ../data/66746.json
# Added ../data/66746.json to ../data/all.json
# Processing ../data/66747.json
# Added ../data/66747.json to ../data/all.json
# Processing ../data/66748.json
# Added ../data/66748.json to ../data/all.json
# Processing ../data/66749.json
# Added ../data/66749.json to ../data/all.json
# Processing ../data/66750.json
# Added ../data/66750.json to ../data/all.json
# Processing ../data/66751.json
# Added ../data/66751.json to ../data/all.json
# Processing ../data/66752.json
# Added ../data/66752.json to ../data/all.json
# Processing ../data/66753.json
# Added ../data/66753.json to ../data/all.json
# Processing ../data/66754.json
# Added ../data/66754.json to ../data/all.json
# Processing ../data/66755.json
# Added ../data/66755.json to ../data/all.json
# Processing ../data/66756.json
# Added ../data/66756.json to ../data/all.json
# Processing ../data/66757.json
# Added ../data/66757.json to ../data/all.json
# Processing ../data/66758.json
# Added ../data/66758.json to ../data/all.json
# Processing ../data/66759.json
# Added ../data/66759.json to ../data/all.json
# Processing ../data/66760.json
# Added ../data/66760.json to ../data/all.json
# Processing ../data/66761.json
# Added ../data/66761.json to ../data/all.json
# Processing ../data/66762.json
# Added ../data/66762.json to ../data/all.json
# Processing ../data/66763.json
# Added ../data/66763.json to ../data/all.json
# Processing ../data/66764.json
# Added ../data/66764.json to ../data/all.json
# Processing ../data/66765.json
# Added ../data/66765.json to ../data/all.json
# Processing ../data/66766.json
# Added ../data/66766.json to ../data/all.json
# Processing ../data/66767.json
# Added ../data/66767.json to ../data/all.json
# Processing ../data/66768.json
# Added ../data/66768.json to ../data/all.json
# Processing ../data/66769.json
# Added ../data/66769.json to ../data/all.json
# Processing ../data/66770.json
# Added ../data/66770.json to ../data/all.json
# Processing ../data/66771.json
# Added ../data/66771.json to ../data/all.json
# Processing ../data/66772.json
# Added ../data/66772.json to ../data/all.json
# Processing ../data/66773.json
# Added ../data/66773.json to ../data/all.json
# Processing ../data/66774.json
# Added ../data/66774.json to ../data/all.json
# Processing ../data/66775.json
# Added ../data/66775.json to ../data/all.json
# Processing ../data/66776.json
# Added ../data/66776.json to ../data/all.json
# Processing ../data/66777.json
# Added ../data/66777.json to ../data/all.json
# Processing ../data/66778.json
# Added ../data/66778.json to ../data/all.json
# Processing ../data/66779.json
# Added ../data/66779.json to ../data/all.json
# Processing ../data/66780.json
# Added ../data/66780.json to ../data/all.json
# Processing ../data/66781.json
# Added ../data/66781.json to ../data/all.json
# Processing ../data/66782.json
# Added ../data/66782.json to ../data/all.json
# Processing ../data/66783.json
# Added ../data/66783.json to ../data/all.json
# Processing ../data/66784.json
# Added ../data/66784.json to ../data/all.json
# Processing ../data/66785.json
# Added ../data/66785.json to ../data/all.json
# Processing ../data/66786.json
# Added ../data/66786.json to ../data/all.json
# Processing ../data/66787.json
# Added ../data/66787.json to ../data/all.json
# Processing ../data/66788.json
# Added ../data/66788.json to ../data/all.json
# Processing ../data/66789.json
# Added ../data/66789.json to ../data/all.json
# Processing ../data/66790.json
# Added ../data/66790.json to ../data/all.json
# Processing ../data/66791.json
# Added ../data/66791.json to ../data/all.json
# Processing ../data/66792.json
# Added ../data/66792.json to ../data/all.json
# Processing ../data/66793.json
# Added ../data/66793.json to ../data/all.json
# Processing ../data/66794.json
# Added ../data/66794.json to ../data/all.json
# Processing ../data/66795.json
# Added ../data/66795.json to ../data/all.json
# Processing ../data/66796.json
# Added ../data/66796.json to ../data/all.json
# Processing ../data/66797.json
# Added ../data/66797.json to ../data/all.json
# Processing ../data/66798.json
# Added ../data/66798.json to ../data/all.json
# Processing ../data/66799.json
# Added ../data/66799.json to ../data/all.json
# Wrapping file in json format
# All data stored in ../data/allfinal.json

# %% [markdown]
# ## Part 2: Converting the JSON file to CSV

# %%
## TEMP: correct shitty formatting errors from API
## store command line commands for now, see if error still persists next week
#sed -r -i.bak 's/\[\]\}\]\}\{\"ass/\[\]\}\,\{\"ass/g' allfinal.json
#sed -r -i.bak 's/\[\]\}\]\}\{\"clean/\[\]\}\,\{\"clean/g' allfinal.json

# %%
## adapted rom https://gist.github.com/tjvc/12e393c48e0025509021

from collections import OrderedDict
import csv
import json
import sys

infile = "../data/allfinal.json"
outfile = open("../data/playerdata.csv", "w")

writer = csv.writer(outfile, delimiter=",")

data = json.load(open(infile), object_pairs_hook=OrderedDict)

# Recursively flatten JSON
def flatten(structure, key="", path="", flattened=None): 
    if flattened is None:
        flattened = OrderedDict()    
    if type(structure) not in(OrderedDict, list):
        flattened[((path + "_") if path else "") + key] = structure    
    elif isinstance(structure, list):
        for i, item in enumerate(structure):
            flatten(item, "", path + "_" + key, flattened)    
    else:
        for new_key, value in structure.items():
            flatten(value, new_key, path + "_" + key, flattened)    
    return flattened

# Write fields
fields = []
for result in data:
    flattened = flatten(result)
    for k, v in flattened.iteritems():
        if k not in fields:
            fields.append(k)
writer.writerow(fields)
print "Flattened JSON to the following fields:"
print fields

# Write values
for result in data:
    flattened = flatten(result)
    row = []
    for field in fields:
        if field in flattened.iterkeys():
            row.append(flattened[field])
        else:
            row.append("")
    writer.writerow(row)
print "Stored CSV as " + outfile.name
# Out:
# Flattened JSON to the following fields:
# [u'__assist', u'__clean_sheet', u'__goal', u'__matchday', u'__game_play_duration', u'__total_earnings', u'__matches_info__away_shortname', u'__matches_info__away_squad', u'__matches_info__away_score', u'__matches_info__time_on_pitch', u'__matches_info__player_status_status', u'__matches_info__player_status_id', u'__matches_info__player_status_match_id', u'__matches_info__period', u'__matches_info__finished', u'__matches_info__home_shortname', u'__matches_info__home_squad', u'__matches_info__home_score', u'__matches_info__player_status_in_for_player', u'__matches_info__player_status_sub_in_timestamp', u'__matches_info__player_status_sub_in_minutes', u'__matches_info__player_status_sub_out_minutes', u'__matches_info__player_status_sub_out_timestamp', u'__shot_on_target', u'__attempt_saved', u'__successful_pass']
# Stored CSV as ../data/playerdata.csv

# %%
print "Started at " + str(datetime.datetime.fromtimestamp(start_time))
print "Finished at " + str(datetime.datetime.fromtimestamp(time.time()))
